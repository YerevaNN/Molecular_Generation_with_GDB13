# %%
import random
import json
import pandas as pd
import selfies as sf
from tqdm import tqdm
from rdkit import Chem
import matplotlib.pyplot as plt

# %%
df_sas_selfies = pd.read_csv("data-bin-sas-selfies.csv", names=["ppl", "selfies"])
df_sas_selfies
# Out:
#        ppl                                            selfies
# 0     1.77  [C][=C][C][C][C][N][Ring1][Branch1][C][=Branch...
# 1     1.81  [C][N][C][=N][N][=C][Branch1][C][C][N][=C][Rin...
# 2     1.64  [C][C][=C][C][=Branch1][C][=O][NH1][C][Branch1...
# 3     1.61  [C][C][=Branch1][C][=O][C][C][=Branch1][C][=O]...
# 4     1.61  [C][C][Branch1][C][C][C][C][O][C][=Branch1][C]...
# ...    ...                                                ...
# 5118  1.72  [N][C][=C][C][=C][C][=C][NH1][C][Ring1][=Branc...
# 5119  1.62  [C][C][=C][Branch1][=Branch1][C][Branch1][C][N...
# 5120  1.61  [C][=C][Branch1][=N][C][C][=C][N][=C][Branch1]...
# 5121  1.73  [C][N][C][=C][C][=C][C][=C][Ring1][=Branch1][C...
# 5122  1.67  [O][=C][Branch1][Branch2][C][C][C][O][C][Ring1...
#
# [5123 rows x 2 columns]

# %%
def make_canonical_smiles(selfies):
    canon_smiles = None
    smiles = sf.decoder(selfies)

    try:
        canon_smiles = Chem.MolToSmiles(Chem.MolFromSmiles(smiles))
    except:
        pass  

    return canon_smiles

# %%
df_sas_selfies["smiles"] = df_sas_selfies["selfies"].apply(make_canonical_smiles)

# %%
df_sas_selfies
# Out:
#        ppl                                            selfies
# 0     1.77  [C][=C][C][C][C][N][Ring1][Branch1][C][=Branch...  \
# 1     1.81  [C][N][C][=N][N][=C][Branch1][C][C][N][=C][Rin...
# 2     1.64  [C][C][=C][C][=Branch1][C][=O][NH1][C][Branch1...
# 3     1.61  [C][C][=Branch1][C][=O][C][C][=Branch1][C][=O]...
# 4     1.61  [C][C][Branch1][C][C][C][C][O][C][=Branch1][C]...
# ...    ...                                                ...
# 5118  1.72  [N][C][=C][C][=C][C][=C][NH1][C][Ring1][=Branc...
# 5119  1.62  [C][C][=C][Branch1][=Branch1][C][Branch1][C][N...
# 5120  1.61  [C][=C][Branch1][=N][C][C][=C][N][=C][Branch1]...
# 5121  1.73  [C][N][C][=C][C][=C][C][=C][Ring1][=Branch1][C...
# 5122  1.67  [O][=C][Branch1][Branch2][C][C][C][O][C][Ring1...
#
#                                                  smiles
# 0     C=C1CCCN1C(=O)OC(C)(C)CCN1CCCC1CNCn1cnc(=O)c2c...
# 1     CNc1nnc(C)nc1CCOCCC(C)=NNc1ncccc1NCN=C(NCCN)NC...
# 2           Cc1cc(=O)[nH]c(NCCN)c1COCNC(=O)Nc1cccc(O)c1
# 3                            CC(=O)CC(=O)c1ccc(CO)[nH]1
# 4          COCCc1[nH]c(=O)[nH]c1CCCc1nncn1C(=O)OCCC(C)C
# ...                                                 ...
# 5118                              Nc1cc2ccc[nH]c-2cc1=O
# 5119          Cc1c(C(N)=O)ncn1CCCNCC(C)n1ncnc1N1CC(N)C1
# 5120     C=C(Cc1cnc(C)nc1)C(C)CCCCC(C)=C(C(=O)O)C(=O)CC
# 5121        CCC(=CC1OCC=Cc2c(NC)cccc21)c1cc(N)cc(Cl)c1N
# 5122                                O=C(CC1COC1)c1cscn1
#
# [5123 rows x 3 columns]

# %%
with open("../Generations_aspirin_0.4/aspirin_unique_canonical_40M.csv", "r") as f:
    generation_aspirin = f.read().splitlines()
    
len(generation_aspirin)
# Out:
# 2978371

# %%
with open("../Generations_sas_3_selfies/sas_unique_canonical_40M.csv", "r") as f:
    generation_sas = f.read().splitlines()
    
len(generation_sas)
# Out:
# 1125025

# %%
gdb_df = pd.read_csv("/mnt/xtb/knarik/GDB13_every100_row.csv")
    
len(gdb_df)
# Out:
# 9743527

# %%
gdb_df.head()
# Out:
#     id      name  sascore  aspirin_similarity
# 0  100  C=CC1CN1   4.2884              0.0294
# 1  200   NC1CC1O   3.0288              0.2162
# 2  300  C=CCC#CC   3.7369              0.0385
# 3  400  CCC1CCN1   3.0331              0.0455
# 4  500  C=NN=CCC   4.3920              0.0312

# %% [markdown]
# ### Creating non generated subsets: sas

# %%
sas_subset = gdb_df[gdb_df['sascore'] <= 3]["name"].values
len(sas_subset)
# Out:
# 66692

# %%
set_sas_subset = set(sas_subset)
set_generation_sas = set(generation_sas)

# %%
not_generated_sas = set_sas_subset - set_generation_sas
len(not_generated_sas)
# Out:
# 59571

# %%
not_generated_sas
# Out:
# {'NCc1ccnc(CNC=O)c1',
#  'CCNc1ccoc1OCC(N)=O',
#  'CCc1cnc(CO)n(O)c1=O',
#  'CNc1c(C)cnc2[nH]ccc12',
#  'Cc1cnc(N)c(O)c1C',
#  'Nc1ccn(O)c1CC(=O)N1CC1',
#  'CC(C)(C)Oc1c[nH]c(C(N)=O)c1',
#  'C=C(CCCNC)OCC(=O)OC',
#  'CN(CCCC1CC1)C(N)=S',
#  'CN(CC#N)CCCCCO',
#  'CC=C(C)CCNCCCCOC',
#  'COc1cc2cccc(O)c2n1N',
#  'CNCCOC(C(=O)O)=C(C)C',
#  'Cc1c(N)cc(C=CO)cc1O',
#  'NN=Cc1cc(N)cc(O)c(=O)c1',
#  'N=C(N)c1ccc(Cl)cc1C(=N)N',
#  'CC(=C(CCO)C(=O)O)N1CCC1',
#  'Cc1ccccc1C=CC=NN',
#  'CC(=O)Nc1nn(C)c(=O)nc1C',
#  'C#Cc1c(C)cccc(NC)c1=O',
#  'Cc1oc(=O)c(C#N)c2c1CCC2',
#  'CCC(CC)=C(C)C(=O)CC1CC1',
#  'CC(C)(O)c1sccc1C1CC1',
#  'C=C(C=CC(=O)OCC)CCOC',
#  'O=C(OC=NO)c1cccc(O)c1',
#  'CC1C(=O)c2cccc(N)c2C1=O',
#  'CCCNN=c1occcc1OC',
#  'N=C(N)C=CCCN1CCCCC1',
#  'CCC(C)C(=O)COC1CCCC1',
#  'CC1(NCC2(N)CCCCC2)CC1',
#  'CCCN1CC(C2=CC=CCC2)C1',
#  'CCOCOCC(=O)NNC(C)=O',
#  'Cc1ccc(CO)c2c(Cl)c[nH]c12',
#  'CCOCCC1=CCCN(C)CC1',
#  'COCCC1CCCCCCN1',
#  'N#Cc1c(Cl)ccn1C(=O)C1CC1',
#  'Cn1cc(CCN)c(CCCO)n1',
#  'CC(CN)NC(=O)C1CCCC1',
#  'C=CCCCCCOCC(=O)NN',
#  'CCCOC(=O)Cc1cocc1N',
#  'CC(=CC(=O)N1CC1)S(=O)(=O)O',
#  'CCc1c(O)c(O)cn1CCOC',
#  'CC(C)CCCC(CCN)C(=O)O',
#  'CC(C)=CCn1cccc(C)c1=O',
#  'COc1cc(C)c(Cl)c2sccc12',
#  'CC=Cc1sc(C)cc1CCC',
#  'Clc1cncn2cc(N3CC3)nc12',
#  'CCC(C)(CC)OCOCCCO',
#  'CN1CCc2c(N)ccc(C#N)c21',
#  'CCc1nnc2scc(C(=O)O)n12',
#  'CCOCCCCNc1ncon1',
#  'COc1cn(C)nc1-c1ncc[nH]1',
#  'COc1c([N+](=O)[O-])c[nH]c1C1CC1',
#  'C=COc1ccncc1C(=O)CO',
#  'COCC(=Cc1ccc(C)o1)CN',
#  'CNCC(CCC(=O)O)COC',
#  'Cc1nc(N2CC2)c(N)c2c1CC2',
#  'C=C(CNCC)c1[nH]c(C)cc1C',
#  'Cc1nccc2cc(C)n(C)c12',
#  'COC(=O)c1cnc2occcc1-2',
#  'C=C(C)c1ncoc1CCN1CC1',
#  'OCC=CCC1CCC(O)CC1',
#  'CN(CCOCC=O)C1CC1',
#  'CC(N)=CC(=O)Cc1cc(C)no1',
#  'Cc1nc2c(c(C)c1CCO)CO2',
#  'CNNC(=O)N(C)CCC(=O)O',
#  'NCCNCCCc1nc(N)cs1',
#  'CC(=O)C1(CCCCCO)COC1',
#  'N#CCCCCCCCC1CCC1',
#  'Cc1onc(C(=O)NNC=O)c1C',
#  'Cc1nc(N)nc(C2COC2)n1',
#  'CNc1cccc2c1CN(C)C2=N',
#  'Cc1nc2ccn(O)c2ccc1=O',
#  'C=COc1c(O)cc(C#N)cc1Cl',
#  'CCCC(=O)c1cnoc1CCO',
#  'CCCNS(=O)(=O)CNCC',
#  'CC(=O)NC(C)=C(C)C(C)(C)C',
#  'C=C(C)Cc1c(CC)oc(C)c1C',
#  'C=CCC(=O)CCCCOCC#N',
#  'CC#CCOCCNCCC(C)C',
#  'CCCCCc1nc(C)c(C)n1N',
#  'Cc1nccc(Cl)c1C(=O)NN',
#  'CNc1c(C)noc1-n1cccc1',
#  'COC(=O)C1(CN)CCCCCC1',
#  'CC(=O)C(C)N(CCO)CC(C)C',
#  'COC(=O)NCc1nc(O)c(C)s1',
#  'CCC(O)c1cc(=O)cccc1C',
#  'CCCCC(=CC(=N)N)CCCC',
#  'CCN(CC)CCC1(NC)COC1',
#  'CNCC=COCc1ccncc1',
#  'Cc1cn2c(n1)-c1c(Cl)cccc1-2',
#  'CC(=N)N(C(N)=O)C1CCCCC1',
#  'CNCc1nc(C)c(CN)cc1Cl',
#  'CCC(CCN)C(=O)N1CC(O)C1',
#  'O=CCNN=CNc1ccccc1',
#  'O=C(C1CCO1)N1CC(CCO)C1',
#  'N#Cc1c(S(=O)(=O)O)ccnc1N',
#  'Cc1ccoc1C1CCC1',
#  'COc1nn(C)c2ccsc12',
#  'CCCc1ccnc2nsnc12',
#  'CNc1c(N)[nH]c(C)c1CC(=O)O',
#  'CCC(=O)CNCCOCC1CC1',
#  'CC(=CCCO)COC(=O)C(C)C',
#  'Cc1csc(-c2sccc2C=O)c1',
#  'OCCCCOCCN1CCC1',
#  'CC(C)CNCCCCONC=O',
#  'CC(C)=NNC(=O)Cc1ncco1',
#  'c1c(OC2COC2)sc2c1CCC2',
#  'CCOC(C)(C)Cc1csc(C)n1',
#  'COCCc1c(N)ncnc1CO',
#  'c1c(N2CCCC2)sc2c1OCC2',
#  'CC(C)Nc1ccsc1C(C)(C)N',
#  'NC(=S)Nc1cnc2c(c1)C(=O)N2',
#  'C=C(C)C(CCCC)NCC1CC1',
#  'ON=C(CN1CCC1)c1ccsc1',
#  'CCCc1cc(Cl)cnc(N)c1=N',
#  'O=COc1cccc(CO)c1CO',
#  'NCCOc1ccnc(N)c1CO',
#  'CC=C(C(=O)N1CC1)C(=O)N1CC1',
#  'O=C(O)c1c[nH]c2cscc12',
#  'COc1cnc2c(c1)cc(O)n2N',
#  'Nc1ncnc(S(=O)(=O)O)c1CO',
#  'CCN(CC(=O)O)C1CNC1',
#  'Cc1sc(CCN)c(C(=O)O)c1N',
#  'CCN(CCO)c1ncncc1N',
#  'CNS(=O)(=O)c1n[nH]c(=O)cc1C',
#  'CCc1cccc(CN)c1',
#  'CC(=CC=CCO)C(=O)OC(C)C',
#  'NC1CN(C(=O)C2(O)CCC2)C1',
#  'CCOCCCC(=O)C=CC=O',
#  'Cc1cnc(NC2(C)COC2)nc1',
#  'Nc1cccc2oc(C=O)nc12',
#  'C=C(CO)OCCCCNCCO',
#  'CCCNC1(C#N)CN(C(C)C)C1',
#  'CC#CCCOCCCCC(=N)N',
#  'CC(C)=CCN(C(=O)NN)C1CC1',
#  'NC(c1ccccc1)C(O)CO',
#  'Cc1ncc(COCC(C)C)s1',
#  'Nc1ncnc(N)c1C(=O)C1CC1',
#  'COCCC(O)CCCCNC=O',
#  'C=Cc1cnccc1-n1ccnn1',
#  'CNC(CN)CCCCNC(N)=O',
#  'CCC(=N)N1CCCC(=O)CCC1',
#  'CC(C)(N)c1c(CO)ccnc1N',
#  'COCCCCOc1[nH]ccc1N',
#  'CCOCc1nc(C(C)C)oc1N',
#  'Cc1c(O)ccc2sc(O)c(C)c12',
#  'CCCNC(=S)NC(=O)COC=O',
#  'CN=CNC(=O)N1CCC(C)CC1',
#  'CC=C(CN(C)C)C(=O)O',
#  'OCc1cc(N2CC2)nn1C1CC1',
#  'COCC(CCN1CCCC1)=NO',
#  'Cc1cc(Cl)c(=O)nc2c1C(=O)N2',
#  'CCn1ccnc1OCC(=O)CO',
#  'C=Cc1occc1CCN1CCC1',
#  'Nc1csc(CCN2CC(=O)C2)c1',
#  'CC(C)CNC1(C)CN(C(N)=O)C1',
#  'Cc1ccc(CN(C)C)c(=NO)o1',
#  'C=Cc1cc2cc(C)oc2cc1C',
#  'C=COc1cc(O)c(C)cc1OC',
#  'CC(C)(O)CCOC(=O)C=CCN',
#  'C=C(OC)c1cccnc1C=CC',
#  'CCCCC(C)OC1CC(CC)C1',
#  'CCc1[nH]cc(C(C)(C)C)c1CC',
#  'Cc1sccc1C1(C(N)=O)CCC1',
#  'O=S(=O)(C(CO)CO)C1CCCC1',
#  'COc1cc(OC(N)=O)cnc1C',
#  'CCCCC=COCCCOCC',
#  'COc1ccncc1C1CCN1C',
#  'NC(=O)Cc1c(Cl)cnncc1=O',
#  'C=CC(C)(C)CNCCCO',
#  'CCCOC1CC(OC)(C2CC2)C1',
#  'CCCNn1c(C)cc(C)c1O',
#  'CNc1cc(C)c2c(n1)COCC2',
#  'N#CCCCNCCOCC(=N)N',
#  'Nc1cc2c(cc1N)CC(O)C2',
#  'CC(=O)C(=O)c1[nH]c(=O)cnc1C',
#  'CCNCc1c[nH]c(=O)cn1',
#  'CCCOCCON=CCCCO',
#  'CCc1c(N(C)C(C)C)noc1C',
#  'CCCC(=O)NC1=CCCOCC1',
#  'COc1c[nH]c(NC(C)=O)c1C=O',
#  'COC(=O)NN=Cc1sccc1C',
#  'CCNc1cc(N)cnc1C(N)=O',
#  'CCCCCCCCC(O)C(=O)O',
#  'CC(C)(NC(=O)OC1CC1)C1CC1',
#  'NCc1cc(NCCO)ccc1N',
#  'COc1ccc2c(N)n(O)nc2c1',
#  'Cc1onc(CO)c1CNC1CC1',
#  'C#Cc1c(C)cc(NNC)cc1Cl',
#  'CCOc1ccc(O)n2ccnc12',
#  'CCCCCOCC#CCNCC',
#  'CN(C)C(C)(C)CCC(N)=O',
#  'CCNCc1cccc2ncnn12',
#  'O=C(CNCCc1c[nH]cn1)NO',
#  'CCCCN(N)C(=S)NCCOC',
#  'COCCn1nc(N)cc1CCN',
#  'Cc1c(N2CC2)cn2ccncc12',
#  'Nc1cc2c(cc1CCCO)CO2',
#  'CCc1cc(C(=O)O)sc1C(C)C',
#  'Cc1cccc(C2(N)CC(O)C2)n1',
#  'Cc1cc2cocc2cc1CCN',
#  'CC1(C)CCCCN(CC=NO)C1',
#  'CCCOC(=O)CC(=COC)OC',
#  'CCNc1cc2scc(C)c2cn1',
#  'CCOCCC=C(C#N)C(C)=O',
#  'C=CCN(CCN1CC1)C(=S)NO',
#  'C=C(CC)CCCc1noc(C)n1',
#  'COCCOCc1nc(N)ns1',
#  'Nc1nccnc(NCCO)c1=O',
#  'CNN=CCc1cncc(CO)c1',
#  'COc1nsc2c(=O)ncccc12',
#  'CCCC#CCCc1ccnnc1',
#  'CC(CNC(=O)C=O)N1CCCC1',
#  'CN(C)CCS(=O)(=O)c1cscn1',
#  'CNC(=O)c1ncn2ccncc12',
#  'Oc1ccsc1CNCC1(O)CC1',
#  'CCOCCOC(=N)NC(=O)OC',
#  'C#Cc1c(Cl)cc(CC)cc1C=C',
#  'CN(CCn1cncn1)C(C)(C)C',
#  'CCS(=O)(=O)c1csc(C)n1',
#  'CCN(C)S(=O)(=O)N(C)CC(=O)O',
#  'CCc1ccnc(NC)c1Cl',
#  'COCC=CCCC(C)(C)CO',
#  'CC(C)C=NOCCNC(=O)CN',
#  'CNc1ccc(C(C)C)c(N)n1',
#  'CCNC(C)(C)CC(=O)N(C)CC',
#  'Nc1ncncc1OCC1CCO1',
#  'Cc1ccc(N2CC2)nc(=NO)c1',
#  'CCCOCC=CNC(=O)C(C)C',
#  'O=C(O)C(=O)CCCC(=O)N1CC1',
#  'CCN(C)c1nccc(=O)nc1C',
#  'CC1=C(CO)CNC(=O)CCC1=O',
#  'Cc1ccc(=O)ccccoc1C',
#  'COc1cc2c(c(C(C)C)c1)CO2',
#  'Cc1nn(C)c(N)c1OC1COC1',
#  'COC(=O)C1=CC(=O)CCCN1',
#  'NS(=O)(=O)c1cccc(=O)c(O)c1',
#  'CCC(=O)c1c[nH]c(NC(C)C)c1',
#  'N=C(N)c1cnc(C2CC2)s1',
#  'CCC(=O)On1cccc1C',
#  'CCC(CC)CCC1(C2CC2)CC1',
#  'N=C(N)CC(=O)NC(=O)CCO',
#  'Cn1cc(CNCCCN)[nH]c1=O',
#  'C=C(OCCC(=O)CC)C(=O)O',
#  'Nc1nnncc1-c1ccco1',
#  'CCCc1ccc([N+](=O)[O-])c(=O)[nH]1',
#  'COCCCOCOC1CN(C)C1',
#  'CCCOCC=C(C)c1cn[nH]c1',
#  'COc1ccc(=N)n(O)c1C',
#  'Cc1onc2ccc(=O)cnc12',
#  'C=CCOc1cc(C=C)c(Cl)cn1',
#  'CN=c1c(Cl)ccc(Cl)c(N)c1Cl',
#  'Nc1cc(CC=O)ccn1',
#  'C=C(c1scc(CC)c1Cl)C1CC1',
#  'O=C(O)c1nccc2c1C(=O)OC2',
#  'NCc1ccc(Cl)c2c1OCC2',
#  'O=C1CCCC2=C1C(=O)OCCC2',
#  'CC=COCC(=O)N1CC(O)C1',
#  'COc1cccc(Cl)c1CN1CC1',
#  'CCN(CCC(=O)N1CC1)C(C)C',
#  'CC=C(C(=O)COC)c1ccco1',
#  'CCOc1c(O)cnc(C)c1N',
#  'Cc1ccc(C=O)c2nccn12',
#  'CN(CCCOCC(N)=O)C1CC1',
#  'CCOCC(=O)COCCOC',
#  'CCN(C)CC(=O)NOC(N)=O',
#  'O=C(CC(O)C1CC1)NC1CCC1',
#  'CCC(=CC=CC(=O)OC)C(=O)O',
#  'CCC(C)(C)c1[nH]cnc1COC',
#  'CCC1CC=Cc2ccccc2O1',
#  'CC(=O)CC1OCCNCCO1',
#  'CNN=CCc1ccc(CN)cc1',
#  'CNNC(=S)NCCOC1COC1',
#  'CCCNC(=O)C1CCC1NCC',
#  'CC(=O)NCCC#CCCC1CC1',
#  'CC1(C)CN1c1ncccc1Cl',
#  'CC(C)=NN1CCCN(C)CC1',
#  'CCc1nc(NN)ccc1C',
#  'CNCCNCC(=O)NOC1CC1',
#  'CN(CC(N)=O)C(=S)NC1CC1',
#  'CCCCCCOC1CC1O',
#  'CC1OCCc2cc(CO)ccc21',
#  'C=Cc1ccc(C)oc(=O)c1=O',
#  'CCN=C(CCOCC)N1CC1',
#  'CCCCC(=O)Oc1[nH]ccc1C',
#  'CCN(CC)C(=O)CC#CC(C)=O',
#  'COCc1nccc(OC)nc1=N',
#  'CCCc1cocc1C(=O)C1CC1',
#  'CCCCCN1CC(N(C)C=N)C1',
#  'CNc1nc(CCCO)ncc1C',
#  'CCOc1ccnc(C(N)=O)c1Cl',
#  'CCCCCOS(=O)(=O)C(=O)OC',
#  'CCCCOc1nnc(CCN)o1',
#  'CCNc1nc(C)cc2c1CN2',
#  'CCc1c(Cl)cncc1CC#N',
#  'CCNc1nccnc1CCNC',
#  'CCc1nc(N2CCC2)c(CC)s1',
#  'CNc1cnc2c(c1Cl)CC2',
#  'Cc1ccc(O)c2nc(C#N)cn12',
#  'CN(C)C(=O)C1CC(C2(O)CC2)C1',
#  'O=C(CCCO)c1ccc(O)o1',
#  'Cn1ccc(CO)c1NC(=O)CO',
#  'CCN1CCNCC(O)CC1',
#  'Nc1scc2[nH]c(=O)c(CO)cc12',
#  'C=Cc1cc(Cl)c(C)c(OC)c1',
#  'CCCc1ncc(S(=O)(=O)O)o1',
#  'COCCn1cnc2c1NC(=O)C2',
#  'CCOc1cc(C(N)=O)[nH]c1CC',
#  'C=C(C)CN(C)C(C)C',
#  'Cc1ccc(NN)c(OC=O)c1',
#  'CN1C(=O)C(=O)c2c(N)cncc21',
#  'C1=CC(CCCN2CCC2)C=C1',
#  'C#Cc1cc(OCC)c(C)nc1C',
#  'CCC(COC)C(=O)N1CCCC1',
#  'O=c1ccncn2ncc(=O)c-2n1',
#  'O=C(NN=CCCO)c1ccc[nH]1',
#  'C=C(COC)COCCNC(C)C',
#  'C=NNc1ccc(CNC)c(O)c1',
#  'O=c1cnncc(OCCO)c1Cl',
#  'Cc1ccn(C(=O)OCC(C)C)c1',
#  'COC(=O)Nc1c(C)cccc1Cl',
#  'CCCn1cc(Cl)c(=O)c(C=O)n1',
#  'COc1csc2c1C=C(C)CCC2',
#  'Cc1cncc2cc(=O)[nH]c(O)c12',
#  'CN1NC=Cc2ccc(CN)cc21',
#  'C#CC(=O)CCC(=O)OC1CCC1',
#  'CCC1CC(OCOCC(C)C)C1',
#  'C=C(CCNNC(C)=O)CC1CC1',
#  'CCOc1cc2c(nn1)C(=O)N2C',
#  'COc1cc(N(C)C2CCC2)cs1',
#  'CCCn1ccc(=N)nc1C(C)C',
#  'Cc1cc(CN)c(O)c(N)c(=O)c1',
#  'Cc1cnccc1-c1csnc1N',
#  'COC(=O)CC(C)CCNC(C)=O',
#  'COC(C)CCN1CCC(C)CC1',
#  'CNC(=O)c1sc(C)c2cc[nH]c12',
#  'CNCCC(N)COCCOC',
#  'CC=Cc1onc(C)c1NC1CC1',
#  'CCn1nncc1CC(=O)C1CC1',
#  'C=Cc1nc(CO)ccc1N(C)C',
#  'CC(C)(O)C(C)(C)C(=O)NN',
#  'C=CCCc1cc(C)cc(OC)c1',
#  'CCOC(=O)N1CC(C)(CCN)C1',
#  'CC(C)(O)c1c(Cl)ccccc1=N',
#  'CN(CCCC(=O)NN)S(C)(=O)=O',
#  'Cn1c(O)cnc1N1CCC1',
#  'COCCC(C)=NOCC(C)C',
#  'CC=C1CCCCCN(CCC)C1',
#  'Cc1cc2c(NN)c(Cl)cnc2[nH]1',
#  'Nc1ccc(CCO)c2ocnc12',
#  'CNc1ccc(N)cc(=O)c(=O)c1',
#  'CC(=O)CCCc1occ(O)c1Cl',
#  'CC=C(CCN1CC1)OCOC',
#  'Cc1cc2nnc(C)n2c(C)c1N',
#  'CCNCC(=O)CCNCC#N',
#  'CCc1nsc(NCC(C)C)n1',
#  'Nc1ncc2c(n1)CC=CCCC2',
#  'C=CC=CCCCCNCC#N',
#  'CCCNc1nc(C)c(COC)o1',
#  'C=CN(C)C(=O)c1ccnc(N)c1',
#  'CCNCc1nncc(C)c1C#N',
#  'Nc1ncc(CC(=O)NC2CC2)s1',
#  'COCC(C)(C)COCCCO',
#  'COCOC1=C(C(N)=O)CCCC1',
#  'CC(C)S(=O)(=O)NCC1CCCC1',
#  'COc1c(OC2CC2)c(C)cn1C',
#  'CON=c1cc(Cl)ccc(OC)n1',
#  'COC(=O)NC(=O)OCC#CCN',
#  'CCN(C=O)Cc1csc(C)n1',
#  'CC=CC#CCOc1ccccn1',
#  'Cn1cncc1C(C)(C)CN1CC1',
#  'N#Cc1cccc(C#N)c1N1CC1',
#  'Cc1ccncc1C(=N)NN',
#  'CCN1CCCn2nnc(C)c2C1',
#  'CC(C)(C)C1CCCC(C(N)=O)C1',
#  'CCCNN1CCCCCOC1=O',
#  'CCNC(=O)CS(=O)(=O)N(C)N',
#  'COc1cc(Cl)cc(C(C)C)n1',
#  'CC=C(C)CCCCO',
#  'CCCCCc1cc(C)c(O)o1',
#  'C=C(C)C=C(C)CCc1ccoc1',
#  'CC=C(CN1CCCC1)C(=O)NN',
#  'CN=C(NCCC1CC1)NC1CC1',
#  'C=CCn1cc(CC)cc(O)c1=O',
#  'CCN1CC(C2(OC)CCCC2)C1',
#  'C=C(COCCOC)C(N)=O',
#  'Cn1cncc1OCc1ccco1',
#  'COn1c(N)cnc1CN1CC1',
#  'OCC=C1CCCCCC1',
#  'CCCC(=O)N(C(C)C)N(C)C',
#  'Cc1[nH]cc(CN(C)C(N)=O)c1C',
#  'CCN(CC)C(=S)N(C)CC(C)=O',
#  'CNS(=O)(=O)Nc1cc(C)ccn1',
#  'CC(=O)OCCC(C)(C)C=O',
#  'O=C(CC1CC1)NN1CCC1=O',
#  'CC(=O)OCc1[nH]cnc(=O)c1C',
#  'CCCn1cncc1CNC(C)=N',
#  'O=c1[nH]cnc2ccccc2o[nH]1',
#  'NCCNc1cc[nH]c1N1CCC1',
#  'O=C(O)c1cc(=O)onc1C1CC1',
#  'COCC(=O)C1CN(CC(N)=O)C1',
#  'Nc1cc(=O)oc(CO)c1N1CC1',
#  'COc1cc(CC2CC2)sc1CO',
#  'CCCOC(=O)NC1CC=CC1',
#  'CCOCC1(C)C(C)(C)C1(C)C',
#  'C=COc1c(C)ccc(C#N)c1O',
#  'OCCNCCOc1sccc1O',
#  'CCC(CC)NCC(=O)NN=CN',
#  'CCOCCC(O)CNC(=O)OC',
#  'Cc1ccc(N2CCC(=O)N2)cn1',
#  'Cc1cnc(NCCN2CCC2)[nH]1',
#  'COn1c(=O)oc2cc(O)ccc21',
#  'O=C(CCCO)N(O)c1ccco1',
#  'O=C(CCN1C=NCC1)OCCO',
#  'CCS(=O)(=O)CC(=O)OCC(=N)N',
#  'CCc1nn2ccc(N)nc2c1C',
#  'Cc1nc2c(c(NCC=O)n1)CC2',
#  'COCCCOCC=CC(=O)OC',
#  'CNS(=O)(=O)N1CCOC(=O)CC1',
#  'OCC#CCCCCn1cccc1',
#  'CCc1c(Cl)cc2ncc(Cl)cn12',
#  'COc1c(N)cc(C)c(Cl)c1NO',
#  'CC=CCc1ccc(O)cc1C',
#  'CC(COCCC(=O)O)C1CC1',
#  'O=CCCCNCCCOCCO',
#  'C=CCNC(=S)NCC(C)CC',
#  'O=C1NCCCc2nccnc2N1',
#  'NCCNc1[nH]cc2c1CCCC2',
#  'Cc1cc(=N)ncn1CCN1CC1',
#  'COC(=O)NNc1ccccn1',
#  'CCc1cc(OC)c(N)n(C)c1=N',
#  'Cc1[nH]cc(NCCO)c1C#N',
#  'Nc1cc2ccc(=O)c(Cl)cc2o1',
#  'CCCCC1=C(OCC)COC1=O',
#  'CCc1cn(C)c(CC)c1CN',
#  'Cc1c(N)cc(CN)n1CC(C)C',
#  'N#CCCc1c(O)cccc1Cl',
#  'COCC#CCc1cccc(N)c1',
#  'c1nc(N2CC2)c2cnoc2n1',
#  'CC(=O)n1nc(C)occcc1C',
#  'O=C(CO)c1cc2sccc2s1',
#  'C=C(CCCNC1CC(C)C1)OC',
#  'CCOc1cnn(C)c1C1CC1',
#  'O=C(CNCC1COC1)OC1CC1',
#  'O=C(O)C1Cc2cc(Cl)cc(Cl)c21',
#  'C=C(C#N)Oc1ccccc1C=O',
#  'O=C(CCOCc1ccc[nH]1)NO',
#  'COCCC1=C(C)CCCNC1=O',
#  'C=C(CCCOCC)COCC#N',
#  'C#CCCCCN(C)CCOC',
#  'CCc1cc(C(=O)O)c2n1CC2',
#  'COCOCCNCC(OC)OC',
#  'C1CC(NC2(C3CC3)CC2)C1',
#  'CC(C)(C)NC(=O)CC=CC#N',
#  'CCCCC(=CC(=O)NN)OCC',
#  'NC(=O)NCCC1COC(=O)OC1',
#  'Cc1c(N)ccc2sc(=O)oc12',
#  'C=Cc1cc(NC)cnc1C(=O)O',
#  'CC1=CCCC=C(C)CCCCC1',
#  'CC(=Cc1ccnnc1)CCN',
#  'Cc1nc(C2CC2)cc(Cl)c(=O)n1',
#  'C=C(NC(=O)COCOC)C(C)C',
#  'C=CC(C)c1c(C)cccc1C',
#  'NC=C(CCc1ccco1)C(=O)O',
#  'CC(C)CCOC(=O)C(CN)CO',
#  'Cc1n[nH]c(OCC2CC2)nc1=O',
#  'CN1C(=O)CC1CC(=O)N1CCC1',
#  'CC(C)=CCC(=O)OCC(=O)CO',
#  'O=C1CC(OCCNCCO)C1',
#  'C=C(C)c1c(O)cc2c(c1Cl)CC2',
#  'CCNC(=S)NCCCNCC#N',
#  'C#Cc1ncccc1OC(=O)NC',
#  'CC(C)c1nc(N)c(N)n1CCO',
#  'CCNC(=O)Nc1sccc1CN',
#  'CC1CC(O)(CC(N)=O)C1',
#  'C=CCN(CC)C(=O)COC(C)C',
#  'O=C1OCCc2c(O)ccnc21',
#  'CCNCCCCC1=NCCCN1',
#  'Cc1ccc(CCN)n1CCCO',
#  'Cc1oc(CC(=O)O)c(N)c1CO',
#  'Cc1nc(N)c(OC(C)C)nc1N',
#  'CCn1c(C2(C)CC2)nccc1=O',
#  'Cc1nc(O)c(C(=O)NN2CC2)s1',
#  'CCNC1(CCNC)CCCC1',
#  'C=C(C)C(CN1CCC1)=C(C)OC',
#  'NC(=O)CCC1(C(=O)C(=O)O)CC1',
#  'C=C(CO)CCOCCOCCO',
#  'CNc1cc(Cl)c(C)nc1NC=O',
#  'CCCC(=O)n1cn[nH]c(=O)c1=O',
#  'N=C(N)CCOCCCO',
#  'CONc1cccc(C(=N)N)c1Cl',
#  'CC(C)C#CCc1cccnc1',
#  'CONC(=NO)NCc1cccs1',
#  'C=C(C=CCCO)CCCCN',
#  'CC(C)Cn1cnc(N)c1C=O',
#  'CC(=NNC(=O)OCC=O)C1CC1',
#  'Cc1ccn2c(C)ncc2c1O',
#  'CCCCOc1coc(=O)cc1N',
#  'CC1(CN2CCCCC2)CC(=O)O1',
#  'CC(=O)c1ncn(CCC=O)c1C',
#  'C=CNC(=O)CCNCCN',
#  'CC=CCN(CC(=O)NC)C(C)C',
#  'COCCCn1nc(N)ncc1=O',
#  'CCc1cc2ncnn2ccc1=O',
#  'COCCCC(=O)N(O)C(C)(C)C',
#  'CC(C(=O)O)=C(N)CCCCN',
#  'Cc1nnc2cncc-2cc1CO',
#  'CCCCc1c(N)cnc(O)c1N',
#  'CCOc1nc2c(c(O)c1C)CC2',
#  'C=Cc1cc(O)c(O)n(CC)c1=O',
#  'CC=C(CC)CCCCC(=O)OC',
#  'COCCC#Cc1cncnc1N',
#  'CNc1nccc2c1CCC(=O)N2',
#  'C=C(CCCC)CNCCCC=O',
#  'CCNS(=O)(=O)N(C)CCCCN',
#  'O=CC=CCCOC1CCCCC1',
#  'CCn1ccc(NC)c1CC(C)=O',
#  'C=CCCCCC1CCOCC1',
#  'Cn1cc(N)c(NCC2CCC2)c1',
#  'CCc1c(O)ccc2nc(C)oc12',
#  'CCCNCCOCC(CO)CO',
#  'COCCOC1CC(C2(O)CC2)C1',
#  'CCCc1ccnc(=NN)cc1C',
#  'CC(C)N(C)CCNCCN1CC1',
#  'C=CCOCc1cccc(C)c1O',
#  'COc1nc(OC)n(CCO)c1C',
#  'CCCCOc1cnc(C)o1',
#  'C#CCN(CCOC(C)C)C(C)C',
#  'CNCCC1OCCCCCCO1',
#  'COc1nc(C)c(CO)cc1N',
#  'NC(=O)C=CC(=O)CCC1CC1',
#  'CC12C3OC45CN6CC41CC6C5C32',
#  'C=CCCNC(CC)CCC',
#  'Nc1cc(=O)[nH]cc1C(=O)NO',
#  'CCCCCCc1ccc(OC)[nH]1',
#  'C=C(CC(C)(C)C)C1CCNCC1',
#  'O=C(O)Cc1ccn2ncnc2c1',
#  'CC(=O)NOC(=O)NN1CCC1',
#  'O=C1NCC1NCCC(=O)N1CC1',
#  'c1cn(-c2[nH]ccc2N2CC2)cn1',
#  'CCCN(NC)C(=O)NC(C)(C)C',
#  'O=CC1CN(C(=O)c2cccs2)C1',
#  'CCc1c(CN)cc(=O)oc1OC',
#  'CCn1cnc2ccc(C)c(O)c21',
#  'CCNCC(CCN1CC1)=NOC',
#  'CCC(c1cccs1)N1CC1',
#  'COCCC1CCN(C)CCN1C',
#  'CCOCCC(C)=NNC(=O)CC',
#  'CCNNC(=O)Nc1sccc1Cl',
#  'CC(C)Oc1c(N)coc1C(=O)O',
#  'CCC(=O)c1noc(N2CC2)c1C',
#  'CC(C)(C)c1c(O)c[nH]c(=O)c1O',
#  'CC(C)NCC=Cc1ccnn1C',
#  'COCCn1c(C)ccc(N)c1=N',
#  'O=C1CCC(CCO)N1C1CC1',
#  'C=CCOCOCCCC(C)C',
#  'COCc1c(O)cc(C)c(O)c1O',
#  'CCCNCC=C(C)CNCCC',
#  'CCCCN(OCC(C)=O)C(N)=O',
#  'COC=CCCOCCOC',
#  'CN=C(C=Cc1ccncc1)NC',
#  'NCc1ccc2ncnn2c1CN',
#  'Cc1cn(CC(C)(C)C)c(O)c1C',
#  'COc1ccc(C(N)=O)ccc1=O',
#  'CCc1cncc(S(=O)(=O)C#N)c1',
#  'NCC(=O)NCCC1(O)CCC1',
#  'CCc1ncc(N(C)C2CC2)nn1',
#  'CCS(=O)(=O)c1ccoc(=O)c1N',
#  'CCCCCCn1ncc(C)n1',
#  'CN(C)CCC(=N)N1CCC1',
#  'Cc1cc2ncsc2cc1C=O',
#  'CCC(CCCCCCO)=NO',
#  'Cc1ccnc(=O)c2nnn(C)c12',
#  'CC1CCC(n2cnnc2N)CC1',
#  'CC(=CCCCN1CC1)C1CNC1',
#  'NC(=O)n1nnc2c(Cl)cccc21',
#  'CC(C)CCCc1cc(N)sc1N',
#  'CCOc1ncc(C=NO)c(C)n1',
#  'Nc1ncc(CO)cc1N1CC1',
#  'CNC1CC(c2nnc(N)n2C)C1',
#  'CCCc1coc(C=O)n1',
#  'C=C(C)c1ccc(CCCN)o1',
#  'CCc1nc(NC)nnc1N(C)C',
#  'COCCC(C)N(C)CCN(C)C',
#  'OCCC=Cc1ccc(CO)nn1',
#  'CN(C(N)=O)C1(CO)CCCCC1',
#  'CCC(=NOCCCCO)N1CC1',
#  'OC1CC(NCCCCC2CC2)C1',
#  'COc1cc(CO)c2ccoc2c1',
#  'Cc1cc(CCCOC(C)C)ns1',
#  'CCOC(C)=C(C)CCCCO',
#  'CN(C(=O)C1CC1)C(=O)S(C)(=O)=O',
#  'O=C1CCCN1C1(CO)CC1',
#  'CNC(=O)C(=O)CN1CC=CCC1',
#  'CNc1ccc2c(C)c(C)[nH]c2c1',
#  'CC(C)C(=O)NNC(=O)C1CCC1',
#  'N=C(CC(=O)NCCC=O)N1CC1',
#  'CC(C)OCCCCOCCC=O',
#  'CCc1coc(N2CCC2)c1O',
#  'CC=CC=CCc1cncc(O)c1',
#  'CCCOC1(CNC2CC2)CC1',
#  'C=C(C)c1cc(C)[nH]c2ccnc1-2',
#  'CCNc1cc2[nH]ncc2nc1N',
#  'CNc1ncsc1NCCC(=O)O',
#  'CNCc1cc(O)cc(C(=N)N)n1',
#  'Oc1cscc1CCCNC1CC1',
#  'CNc1n[nH]c2c(=O)cccnc12',
#  'CCn1cnc(OC)c1C(=O)NN',
#  'Cc1cc(=O)c(N)c2ccoc2c1',
#  'CNC(=O)c1ncoc1C(C)=O',
#  'C=Cc1cc(CC)cc(O)c1Cl',
#  'CCCOC(=O)C(C)(C)C1(O)CC1',
#  'CNCCn1cccc1COC=O',
#  'CCCC=Cc1sc(C)nc1OC',
#  'CCCCN(OCCO)C(=O)CC',
#  'NC(=O)NC(=S)NCCCCO',
#  'c1nsc(CCNC2CCC2)n1',
#  'C#Cc1cc(C=C)c(Cl)cc1Cl',
#  'CCOC(=O)CC1CN(C)CCO1',
#  'CC(C)(CC#N)CCCC(=O)O',
#  'Cc1cc(C2CCC2)cn1C(C)C',
#  'Nc1c(C(=O)O)sc2[nH]ccc12',
#  'CCCNCC(=O)N(CC)C(C)=N',
#  'COc1ccc(N)c(C(O)C=O)c1',
#  'NNC(=O)CC(=O)OCCCCO',
#  'CCc1cc(=O)n(NC)c(N)n1',
#  'CON(C)C(=N)NC(=O)CN1CC1',
#  'CCn1nc(C)cc1CN1CC1',
#  'Nc1ccsc1CCc1ncco1',
#  'CCCn1cc(-c2cnsc2)cn1',
#  'CCCc1c[nH]c(N)c1C(N)=O',
#  'C=COc1ccncc1OCOC',
#  'C=CCC(=O)NNCCCCCN',
#  'CCC#CCNCCC1CCCC1',
#  'O=c1n(CCO)ccn1C1CCC1',
#  'CCCCCc1nc(C)oc1C#N',
#  'CN1CCCC1=C1C(=O)CCC1=O',
#  'CC(CNCCO)C(=O)NCCN',
#  'CCOc1nc(N)nn1CC(C)=O',
#  'Cn1nccc1C=CCCCCO',
#  'C=CCNCCCN1CC(NC)C1',
#  'CN(C=CC(N)=O)C1CCCCC1',
#  'CC(CC(=O)Nc1cccs1)=NO',
#  'C=CCCC(=O)N(C)OCCCC',
#  'COc1[nH]c(CCCO)cc1C',
#  'Cc1cc2[nH]c(=O)sc2nc1C',
#  'CNC=Cc1cc(C)c(Cl)cc1C',
#  'CCNC(=O)COC(C)(C)CN',
#  'C=Cc1ccnc(NCC)c1CC',
#  'Cc1ccc2nscc2c1C(C)C',
#  'OCC#Cc1ccn2ccccc12',
#  'NCC=CCC1CN(CC(N)=O)C1',
#  'CCc1ncc(N)cc1C(=O)C#N',
#  'CC(CC1CCC1)NCC1CCC1',
#  'C#Cc1cc(C)c(S(C)(=O)=O)cn1',
#  'CC(=O)OCC1CCCNC1',
#  'CCCCN(N(C)C)S(C)(=O)=O',
#  'ONC(=S)NCc1cc(Cl)ccn1',
#  'Cc1c2ccc(C#N)cc2nn1C',
#  'CC(=O)C(=Cc1ccco1)CO',
#  'C=CCc1cc2c(c(N)c1O)CC2',
#  'CCCC1CN(CC(C)(C)O)C1',
#  'COc1occ2cc(Cl)c(Cl)cc12',
#  'CCOCc1c(C#N)cnn1CC',
#  'CC#CCC(=O)CCOC',
#  'CCCC(=NO)C1CCC(O)CC1',
#  'CCC(=O)OC(C)CCOCCO',
#  'COCCOC(=O)N(CCN)OC',
#  'O=CNc1ccc2c(c1)CN2C=O',
#  'C=C(CC)c1cnc2c(c1C)CC2',
#  'CCCc1cc(-c2ccoc2)c[nH]1',
#  'CCOC(=O)C=C(CC)OC',
#  'CC(C)=C1CCN(CCCO)CC1',
#  'CCNC(=O)C(=O)Nc1cn[nH]c1',
#  'CCS(=O)(=O)c1cc(C)oc(=O)c1',
#  'O=C(CC1CCC1)c1ccnnc1',
#  'OCCCNCC1CCCNC1',
#  'CC(CO)CCNC(=O)CC#N',
#  'COC(C)=CCC1CN(C2CC2)C1',
#  'C#CCc1cc(C(C)C)ccc1Cl',
#  'CNc1ccn2ncc(O)c2n1',
#  'C=C(CN1CCC1)C(=O)NNC=O',
#  'C#Cc1ccc2c(c1Cl)CCNC2',
#  'CC(=O)c1nc(N(C)C2CC2)cs1',
#  'CC(C)(O)C=CCCc1ccco1',
#  'CCCCN(CCO)CC(N)CC',
#  'CNCCc1ncsc1C(=O)NN',
#  'CCNc1cnn(CC)c1NC',
#  'COc1cncc(=O)c(N(C)C)c1',
#  'COc1ccc(-c2nccnn2)o1',
#  'C=CCc1ccnnc1NC(N)=O',
#  'CNC(=O)COC(=O)N(N)C(C)C',
#  'Cc1scc(N)c1S(=O)(=O)C(C)C',
#  'CCCCNC(=O)ON=CN1CC1',
#  'O=c1ccccn1OC1CCCC1',
#  'C=C(COC(=O)C(=C)C)CN1CC1',
#  'Cn1ncc(N2CC2)c1CC(N)=O',
#  'C=CCOCCC(=O)C1CC(O)C1',
#  'CC(C)CC1(N2CCOCC2)CC1',
#  'CC(C)CC=NOCCCCCN',
#  'CCN(CC)CCC(C)=CC(=O)O',
#  'CNc1cc2c(c(C)c1C)CC=C2',
#  'CCC(C)NC(=O)C(CN)NC',
#  'CC=CCCC=CCCCNC',
#  'C=CCc1cc(N)c(N)c(C)c1C',
#  'NNc1cccnc1NCCCO',
#  'Cc1cc(Cl)c2oc(N)c(C)c2n1',
#  'CCCCCCC(OC)=C(C)CN',
#  'CCCc1cnc(N)cc(Cl)c1=O',
#  'Cc1cc2c(CC3CC3)c[nH]c2[nH]1',
#  'COC(=O)C=CCC(=O)CC(C)C',
#  'CCc1cnc2c(cc1=O)OCO2',
#  'CC(=O)Nc1cnc(=O)nc(C)c1',
#  'Cc1cc(C2CN(CCN)C2)cs1',
#  'CC#Cc1ccc(C#N)c(OC)c1',
#  'CCOCCc1ccc(C(C)=O)[nH]1',
#  'Cc1c(N2CC2)nncc(=O)c1O',
#  'CCC(O)CCOC(=O)C(C)C',
#  'C=C(c1cnn(C)c1)C(CC)CC',
#  'CC(C)(C)C(=O)C(C)(C)OC(N)=O',
#  'N#Cc1cc(CO)ccc(Cl)c1=O',
#  'C=Cc1ccc(C)c(C)n1',
#  'Cc1ccc(C(C)N2CCC2)cc1',
#  'C=CC=CC(=O)N(CC)CC(=C)C',
#  'Cc1ccc(NC2CC(=O)C2)s1',
#  'CNCCC(CCCN)C(=O)NC',
#  'C=CC(=CC)c1cccc(C=C)c1',
#  'COCc1[nH]ccc1OC(=O)CN',
#  'COCc1c[nH]c(=O)cc1C=O',
#  'CC=C1Oc2c(O)cccc2C1=O',
#  'Cc1csc(-c2ccc(C=O)o2)n1',
#  'CC(C)=Cc1cocc2cccc1-2',
#  'CC(=O)c1scc(C(C)C)c1N',
#  'Cc1oc(=O)cc2c1CCOC2=O',
#  'CNc1nnc2cc(O)ccn12',
#  'CC1(C)NCCn2c1cccc2=O',
#  'CN(C)CCC(=O)NCC1CN1C',
#  'CC(CO)=NNc1ncccc1O',
#  'O=c1[nH]c(CN2CCCCC2)ns1',
#  'Cc1cc(CC(C)C)cc(O)n1',
#  'CC(=O)c1ncc(CO)cnc1=O',
#  'COCCOC1(C)CC(O)C1',
#  'C=CCc1cnc(CNC(C)=O)s1',
#  'CC1=NCCN1CCO',
#  'CC(=O)Cc1cc(Cl)c(Cl)cc1N',
#  'C=C(NC=N)C(=O)c1ccccc1',
#  'CC(=O)Nc1cncc(=N)cc1Cl',
#  'CC(C)(CO)CC1CC(CN)C1',
#  'CCC(=O)OC(C)(C)CN',
#  'CCCCOc1n[nH]c(CN)c1Cl',
#  'CCCNc1nn(CC)c(C)c1Cl',
#  'CC(CNC1CC1)=C(C)CN1CC1',
#  'CCCCC(=O)OCC(C)C(C)=O',
#  'Cc1ccc2c(C)noc2n1',
#  'Cc1nc(O)ccc1C1CCCC1',
#  'CON=C(C)OCCOCCCO',
#  'CNc1nc(CCOCOC)ns1',
#  'CNC(=O)OCCOC=CC1CC1',
#  'CCCOc1ccc(Cl)c(=O)n1C',
#  'CNC1CC(C(C)(C)CC(N)=O)C1',
#  'COCCON=C(C)C1CC(C)C1',
#  'Cc1csc(CCC(C)C)c1Cl',
#  'N#CC=C(CCNC(N)=O)C(=O)O',
#  'CC(=O)Nc1nc(O)cnc1C',
#  'NNc1nc2c(CO)cccc2o1',
#  'NC(=O)CCCN1CCC2(CC2)C1',
#  'Cc1nc(CN)c(Cl)cc1CCO',
#  'N#CCNC(=O)c1cc(O)ccn1',
#  'NC(CO)C(=O)NC1COC1',
#  'COCC(=O)CNCC(C)N1CC1',
#  'C=Cc1ccc2c(O)[nH]cc2c1',
#  'CC=CCOCCOCOCCN',
#  'CCCC1(CCC2CC(=O)C2)CC1',
#  'C=Cc1ccc(CC(C)C)o1',
#  'NCc1c(CN2CCC2)noc1O',
#  'Cc1cc(CO)nc(CC=O)c1',
#  'CCNCc1ncccc(=O)n1',
#  'CCCc1ccnc2[nH]cc(C)c12',
#  'Nc1[nH]nc(C(=O)O)c1CC1CC1',
#  'COc1cccc2conc12',
#  'CCCOCC=COCC(=O)OC',
#  'CCN1CCCCN2C(=O)CC2C1',
#  'Cc1sccc1NS(=O)(=O)C(C)C',
#  'O=C(NC1(C2CCC2)CC1)C1CC1',
#  'CNCCc1cc(NC(C)=O)co1',
#  'Cc1csc(O)c1OC(C)C',
#  'OCC(COCC1CC1)N1CCC1',
#  'NC(=O)c1[nH]cc2c1NCCCC2',
#  'COC(CCCN(C)C)C(=O)O',
#  'CCc1ccc(CCNC)cc1Cl',
#  'C#CCN(CC)S(C)(=O)=O',
#  'Cc1nc(C)c(N)c(CCN)c1N',
#  'C#CCn1c2cccc-2nnc1C',
#  'Cc1csc(C)c1[N+](=O)[O-]',
#  'N#Cc1ccc(-n2ccnc2)nn1',
#  'CCCc1coc(CC(=O)CC)n1',
#  'C=CC(=O)N(CCCN)C(C)=O',
#  'Nc1cnc2cnccn2c1=O',
#  'CCc1ncsc1CCCC(=O)O',
#  'Cc1nccc(=O)n1CC(=N)N',
#  'CS(=O)(=O)c1cc2ncccc2[nH]1',
#  'CC(C)(C)COCCCC(=O)NN',
#  'COc1cnccc(C#N)c1=O',
#  'C=C(C(=O)O)C1COCCCOC1',
#  'Cc1ccc(N)c(O)c1OC1CC1',
#  'COCC(=CCC1CC1)C(=O)OC',
#  'CC1CC1NCc1ccc(N)cc1',
#  'Cc1cccn1C1CCC(=O)CC1',
#  'CC1CN(c2ccccc2)CC1=O',
#  'CCC(C)NCCNCC(C)C',
#  'CNCc1cc(C)n(C)c1[N+](=O)[O-]',
#  'Cc1cc(O)c(=O)c(=O)n(C)c1N',
#  'CCCC=CCN(C)CC1COC1',
#  'NCCc1ccc(CO)c(=O)cn1',
#  'C=CC(O)CCC(=O)NC1CCC1',
#  'O=Cc1ccc(C2CC2)cc(=O)n1',
#  'Cc1c(O)cnc(N)c1CCCN',
#  'CC(C)(C)C(O)c1ncccc1Cl',
#  'C=CCCCCCC(N)(CO)CO',
#  'CC1CN(C(=O)c2cc(Cl)cs2)C1',
#  'Nc1ccncc(=NO)c1N1CC1',
#  'COCCC(CCOC)C(C)(C)O',
#  'C=CCC(=O)Cc1cnc(N)nc1',
#  'Cc1ncccc1NC(C)(C)C#N',
#  'CCNNc1nccc(C)cc1=O',
#  'Cc1cc(O)c(CO)cc1N',
#  'O=c1ccnnc(NC2CCC2)c1',
#  'CCCCOCC(C(C)=O)=C(C)C',
#  'CCCC(=CCCN)C(=O)O',
#  'Cn1cc(N)c(CN2CC(O)C2)n1',
#  'NC(=NNC(=O)CO)c1ccsc1',
#  'CC=C1CCCCN(C)CCC1',
#  'C=C(C)C(C)OC(=O)CCC(C)=O',
#  'Cn1cnc(C=CCC(=O)O)c1',
#  'CCCCC=C(C)CNC(=O)NO',
#  'CCOc1ncn(C)c1C(=O)NC',
#  'Cc1c[nH]c(=O)c(C(=N)N)c1C',
#  'CCCc1[nH]nc([N+](=O)[O-])c1C',
#  'CCCc1cn(C(=O)CC)c(N)n1',
#  'Nc1cc(S(N)(=O)=O)[nH]c(=O)c1',
#  'Cn1nccc1CC=CCC(=O)O',
#  'COc1[nH]ncc1-c1cnn(C)c1',
#  'Cc1cccc(Cl)c1CC=NO',
#  'O=C1CC(n2nccc2CO)C1',
#  'O=C1CCCc2oc(C3CC3)nc21',
#  'CCc1nn(CCN)c(OC)c1C',
#  'CC(C)c1[nH]ncc1C(=O)NN',
#  'C=Cc1ccc(COC(N)=O)o1',
#  'N#CC#CCCC(=O)OC1CCC1',
#  'Cc1cc(CCn2ccnc2)cs1',
#  'Nc1csc(CNC2CCC2)c1',
#  'CCC(=O)NC1=C(C)CNCCC1',
#  'N=C(N)CCCN(CCN)CCN',
#  'CC1(CCCCC(=O)NN)COC1',
#  'Cc1nc2noc(CN)nc-2c1C',
#  'CCCCC1(C#N)CC(C(C)=O)C1',
#  'CCOCc1ccc(C)c(CC)n1',
#  'Nc1cc(C=NO)c(N2CC2)cn1',
#  'O=CC1CN(NC(=O)C2CCC2)C1',
#  'COc1c(C)c2c(c(C)c1Cl)CC2',
#  'Cc1ccc(Cl)c(C=O)nc1=O',
#  'C=C(CC)OCCCCC1CCC1',
#  'Cc1cc(CCN(C)C2CC2)no1',
#  'CCOc1cc(C(C)O)cc(N)n1',
#  'N#Cc1ccc(CC(=O)C2CC2)o1',
#  'Cc1oc(=O)cc2c1CN2CCO',
#  'CC(O)(CN)Cc1cccc(N)c1',
#  'O=C(O)C(CO)(CO)CC1CCC1',
#  'Cc1ccsc1COCC1CCC1',
#  'CCCn1ncc(Cl)cc(=N)c1=O',
#  'COCCCC(=O)c1nncs1',
#  'CCC=CC(=O)Oc1ccsc1N',
#  'COCCn1ncc(Cl)c1C(=O)O',
#  'CN=C(Cc1cccs1)N1CCC1',
#  'Cc1nn(C)c2c(N3CC3)noc12',
#  'N=c1cccc(Cl)cc1CC1CC1',
#  'CCCC(=O)c1scc(N)c1C',
#  'O=CCCC(=O)CC1(C(=O)O)CC1',
#  'Cn1c(CN2CCC2)cc(=O)n1O',
#  'CN(C)c1ccnc2cccn12',
#  'C=C(CO)NC(=O)CCCC(C)=O',
#  'CCNC(C)(C)c1cncnc1C',
#  'CCOCCC(=O)CC(C)COC',
#  'Cc1c(N)cc(N)[nH]c1=O',
#  'NCc1n[nH]c(=O)n1C1CCC1',
#  'CCOC(=O)C=C1CN(C)CC1=O',
#  'CC(C)Nc1ccc(C2CN2)cc1',
#  'CCNN=Cc1ccnc(CO)c1',
#  'CCc1nnc(N)n1CC(C)(C)C',
#  'CCc1ncnc2cncn12',
#  'CC(=O)C(=O)NCCn1cnnc1',
#  'CCCc1[nH]c(C(=O)O)cc1CN',
#  'N#Cc1cc(N)cc(NO)c1Cl',
#  'Cc1nc(C#N)c2occc2c1C',
#  'COc1cn(C)c(CCCN)n1',
#  'NCC(=O)OCC=CCC1CC1',
#  'Cn1c(O)c(C(N)=O)c(N)cc1=O',
#  'NC(=O)c1csc2c1CNCC2',
#  'C=C(C=O)c1cccc(Cl)c1NC',
#  'CCCCc1oc(=O)oc1C(C)C',
#  'CC(C)CCn1nc2n(c1=O)CC2',
#  'COc1cc(C)ccc(=NO)c1N',
#  'Cc1c(S(C)(=O)=O)c[nH]c1C(=O)O',
#  'CCN(CC(CO)CO)C(=O)NN',
#  'c1cc(N2CCC2)c2conc2n1',
#  'COCCn1nc(C(N)=O)cc1O',
#  'C=COC(=C)c1cccc(Cl)c1Cl',
#  'COc1cc(C)cn(O)c1=N',
#  'Cc1cc2c(c3cnnc-3n1)OC2',
#  'CC(C)(C)n1ccc(S(N)(=O)=O)c1',
#  'O=CC(=O)c1cccc(C2CN2)c1',
#  'CCCOC1=C(C2CC2)C(=O)OC1',
#  'CCc1c(C)ccnc(=O)c1CN',
#  'COC(=O)C1(N)CN(CCCN)C1',
#  'Cc1cnn2c(=O)cc(C)nc2n1',
#  'C=Cc1c(NC(=O)NC)cnn1C',
#  'CC1CN(C(=O)CCNC(=N)N)C1',
#  'C=Cc1ccc(CC(=C)C)cc1Cl',
#  'Cc1c[nH]c(C2=CCCCCC2)c1',
#  'C(=CC1CCC1)c1ccoc1',
#  'Nc1cc(CNC2CCC2)cnn1',
#  'C=C(OCC)C(=O)CN1CCC1',
#  'CN(C)C(=O)C(CC(=O)O)N(C)C',
#  'CCOC(=O)C(=CC1CC1)OC',
#  'CN1C(=O)c2cc(O)c(N)nc21',
#  'COc1c(C)cn(CC(N)=O)c1N',
#  'COCCCCc1nn(C)c(=O)[nH]1',
#  'CS(=O)(=O)c1ccc[nH]c(=O)c1=N',
#  'CCCNCC1=CC=CC=CC1',
#  'Cc1nsc(N(C)C(=O)CCO)n1',
#  'O=C1CC(c2cc(=O)c(=O)c2=O)C1',
#  'O=C(O)CNC1CCCC(=O)C1',
#  'CCN1CCC(C2(C)CNC2)CC1',
#  'NC(=O)C(=CCC(=O)O)CN1CC1',
#  'CCCCc1ncc(N2CC2)cn1',
#  'C=NNc1cc(CC)c(O)cc1Cl',
#  'CN(C)CC(=O)N1CCN(N)C1=O',
#  'CC(=O)COc1ncc(C)nn1',
#  'CNCc1ccc2nncn(C)c1-2',
#  'CCC(=O)NNC(=O)C1(N)COC1',
#  'COCC1CC(CCC=O)C1',
#  'COCC(=O)c1cc(N)cnn1',
#  'CCc1ccsc1COCCOC',
#  'CNCc1nc(C)c(NCCO)s1',
#  'c1nnc2cc3c(cnc1-2)NCC3',
#  'N=C(N)c1ccc2ccccc2c1',
#  'C1CCCCC(N2CCC2)CCC1',
#  'C=C(OC)c1ccc(C(C)=O)nn1',
#  'CCN(C)Cc1ncc(C)n1C',
#  'CCc1cc(CC2CC(C)C2)no1',
#  'C=C(CCOC(C)=O)C1CC=CC1',
#  'COC(=O)CC1COCCN(C)C1',
#  'Cc1cc2c(c3c1N(C)C3=O)CC2',
#  'CC#Cc1c(O)ccc2sccc12',
#  'Cc1nnc2c(c1C)CCNC2=O',
#  'CNc1cc(NC)cc(NOC)c1',
#  'COc1c(O)ccc2ncn(C)c12',
#  'CCN(C)C(=O)CC#CCN1CC1',
#  'COCCc1c(OC)noc1CO',
#  'Cc1nn2ccncc2c1CC#N',
#  'CC=C(C)CC#CCCCCCC',
#  'COC(=O)CC(=O)N(C)CC(C)N',
#  'COc1ccc2ncc(N)n2c1',
#  'NNC(=O)NCc1ccsc1CO',
#  'Cc1cccc(NNC2(C)CC2)n1',
#  'CNC1(CN)CN(CCCO)C1',
#  'CCOCOc1ccnn1CCO',
#  'CCc1nn(C)c(CCOC)c1Cl',
#  'COc1ccc(C)c(C=O)c1C#N',
#  'O=C(O)c1ccccn[nH]c(=O)[nH]1',
#  'O=c1cc(CO)c2c(o1)CCCO2',
#  'O=c1cnc2ccsc2cc1CO',
#  'COCCCC(C)C(=O)OC1CC1',
#  'O=CC=Cc1ccc2nonc2c1',
#  'CNc1ncccc(CN)c1=N',
#  'COCCC1CN(c2ccco2)C1',
#  'CNn1cc(O)c2cccc(Cl)c21',
#  'c1ccc2c(c1)NCc1nonc1-2',
#  'CC=CCCC(=O)NCC(O)CO',
#  'CC(C)c1occc1O',
#  'CC(C)COC=CC(=O)CC(C)C',
#  'CCOC(=O)CCCCNCCO',
#  'CC(=O)Oc1ncnc(CN)c1N',
#  'CNc1c(OCOC)cc(C)n1C',
#  'Cc1ccc(N)cc(O)c1=NN',
#  'CCCCn1cncc1CC=O',
#  'CCC(C)(C)OCCc1ccco1',
#  'NCC(=O)OCCCC#CC(=O)O',
#  'CC(=O)Nc1ccnc(CN)n1',
#  'Nc1ccnc(OC=O)c1N1CC1',
#  'COc1cc(Cl)c2c(=O)o[nH]c2c1',
#  'N=c1sccn1CC1CCNCC1',
#  'CCCC(=O)CCCOC(C)CO',
#  'CON(C)C(=O)CC(=O)CN(C)C',
#  'CC(C)c1nc(O)cnc1N1CC1',
#  'CCCc1ncccnc1=NO',
#  'CCCc1cc(C(C)(C)C)oc1O',
#  'CC1CCCC1Cc1ccncc1',
#  'CCCCOn1c(C)n[nH]c1=O',
#  ...}

# %%
not_generated_sas = list(not_generated_sas)
random.shuffle(not_generated_sas)

# %%
with open(f"../data-bin/data-subsets/gen_sas_selfies.jsonl", "w") as f:
    for smi in tqdm(generation_sas):
        # Write
        selfies = sf.encoder(smi)
        new_line = {"text": selfies}
        json.dump(new_line, f)
        f.write("\n")
# Out:
# 100%|███████████████████████████████| 1125025/1125025 [03:53<00:00, 4809.08it/s]

# %% [markdown]
# ### Creating non generated subsets: aspirin

# %%
aspirin_subset = gdb_df[gdb_df['aspirin_similarity'] >= 0.4]["name"].values
len(aspirin_subset)
# Out:
# 82760

# %%
set_aspirin_subset = set(aspirin_subset)
set_generation_aspirin = set(generation_aspirin)

# %%
not_generated_aspirin = set_aspirin_subset - set_generation_aspirin
len(not_generated_aspirin)
# Out:
# 62897

# %%
not_generated_aspirin = list(not_generated_aspirin)
random.shuffle(not_generated_aspirin)

# %%
with open(f"../data-bin/data-subsets/gen_aspirin.jsonl", "w") as f:
    for smi in tqdm(generation_aspirin):
        # Write
        new_line = {"text": smi}
        json.dump(new_line, f)
        f.write("\n")
# Out:
# 100%|█████████████████████████████| 2978371/2978371 [00:22<00:00, 132811.17it/s]

# %%
with open(f"../data-bin/data-subsets/gen_sas_selfies.jsonl", "r") as f:
    d = json.load(f)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[7], line 2
#       1 with open(f"../data-bin/data-subsets/gen_sas_selfies.jsonl", "r") as f:
# ----> 2     d = json.load(f)
#
# File ~/miniconda3/envs/gdb/lib/python3.10/json/__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#     296         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#
# File ~/miniconda3/envs/gdb/lib/python3.10/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~/miniconda3/envs/gdb/lib/python3.10/json/decoder.py:340, in JSONDecoder.decode(self, s, _w)
#     338 end = _w(s, end).end()
#     339 if end != len(s):
# --> 340     raise JSONDecodeError("Extra data", s, end)
#     341 return obj
#
# JSONDecodeError: Extra data: line 2 column 1 (char 95)

# %%
data = []
with open(f"../data-bin/data-subsets/gen_sas_selfies.jsonl", "r") as f:
    for line in f:
        data.append(json.loads(line))

# %%
data[:1000]
# Out:
# [{'text': '[C][C][N][C][C][C][Branch1][C][C][=C][Branch1][Ring1][C][C][C][=Branch1][C][=O][O]'},
#  {'text': '[C][C][=Branch1][C][=O][N][C][C][=C][C][=C][C][=Branch1][C][=O][C][Ring1][Branch2][=O]'},
#  {'text': '[C][N][Branch1][C][C][C][C][N][Branch1][Ring2][C][C][=O][C][C][C][C][Ring1][Ring2]'},
#  {'text': '[C][C][N][C][=C][C][Branch1][C][C][=C][C][Branch1][C][Cl][=C][Ring1][Branch2][C][C]'},
#  {'text': '[C][C][=C][C][=C][Branch1][N][C][=Branch1][C][=O][C][C][C][N][Ring1][Ring2][C][O][Ring1][N]'},
#  {'text': '[C][N][Branch1][Branch2][C][C][C][C][C][Ring1][Ring1][C][=Branch1][C][=N][C][C][=Branch1][C][=N][N]'},
#  {'text': '[C][C][C][=N][C][Branch1][Ring1][N][C][=C][C][Branch1][C][O][=C][Ring1][=Branch2][C][C]'},
#  {'text': '[C][C][C][=C][C][=Branch1][C][=O][N][=C][Branch1][Ring1][C][N][N][Ring1][=Branch2][C]'},
#  {'text': '[C][N][C][C][C][C][C][=Branch1][C][=O][N][C][=Branch1][C][=O][N][C]'},
#  {'text': '[C][C][C][C][C][Branch1][C][C][Branch1][=Branch2][C][N][C][C][=Branch1][C][=O][O][C][Ring1][O]'},
#  {'text': '[C][C][C][C][C][C][=C][Branch1][C][C][N][=C][C][=Branch1][C][=N][C][=Ring1][=Branch2]'},
#  {'text': '[C][C][=C][C][=C][C][=Branch1][Branch1][=C][Ring1][=Branch1][O][N][Branch1][=Branch1][C][Branch1][C][C][C][C][Ring1][=Branch2]'},
#  {'text': '[C][N][C][C][=C][C][Branch1][Ring1][C][O][=C][Branch1][C][O][C][=C][Ring1][=Branch2][O]'},
#  {'text': '[C][C][=Branch1][C][=O][C][=C][C][=C][C][Branch1][C][C][=C][Branch1][C][C][N][Ring1][#Branch1][N]'},
#  {'text': '[C][C][C][C][Branch1][Ring2][C][C][C][N][Branch1][C][C][C][C][C][C][Ring1][Ring1]'},
#  {'text': '[C
#  {'text': '[C][C][Branch1][C][C][N][Branch1][C][C][C][=Branch1][C][=N][C][C][C][C][C][Ring1][Ring2]'},
#  {'text': '[C][C][=C][C][=C][C][Branch1][O][C][=N][C][=Branch1][C][=N][N][Ring1][#Branch1][O][=N][Ring1][N]'},
#  {'text': '[C][C][N][C][=Branch1][C][=O][N][C][C][N][Branch1][C][C][C][Ring1][=Branch1][=O]'},
#  {'text': '[C][N][Branch1][C][C][C][C][N][C][C][C][C][N][Branch1][C][C][C][Ring1][=Branch1]'},
#  {'text': '[C][C][=Branch1][C][=O][N][Branch1][C][C][C][C][C][C][C][C][Ring1][Ring1][Branch1][C][C][C]'},
#  {'text': '[C][C][Branch1][C][C][N][C][=C][C][=C][Branch1][C][N][N][=C][Ring1][#Branch1][N][N]'},
#  {'text': '[C][C][C][C][C][N][C][C][C][Branch1][C][C][=C][C][O]'},
#  {'text': '[C][C][=C][C][Branch1][C][O][=C][Branch1][C][C][C][Branch1][C][Cl][=C][Ring1][=Branch2][C][C][N]'},
#  {'text': '[C][N][C][C][Branch1][C][C][C][N][C][=Branch1][C][=O][C][C][O]'},
#  {'text': '[C][=C][Branch1][C][C][C][C][C][C][N][Branch1][#Branch1][C][C][=Branch1][C][=O][O][C][Ring1][#Branch2]'},
#  {'text': '[C][C][C][C][C][N][Branch1][=Branch1][C][C][C][Ring1][Ring1][C][C][C][C][Ring1][N][Ring1][Ring2]'},
#  {'text': '[C][=C][C][C][N][C][C][=C][C][Branch1][C][Cl][=C][N][Ring1][=Branch1][C]'},
#  {'text': '[C][C][=C][C][Branch1][C][Cl][=C][C][Branch1][C][N][=C][Ring1][Branch2][C][N][C][C][Ring1][Ring1]'},
#  {'text': '[C][C][C][N][Branch1][C][C][C][C][N][C][C][C][O][C][Ring1][Branch1]'},
#  {'text': '[C][C][=C][C][=C][Branch1][Ring1][C][O][C][=Branch1][C][=N][N][Branch1][C][C][C][Ring1][O][=O]'},
#  {'text': '[C][C][=C][C][Branch1][C][Cl][=C][Branch1][C][C][C][=Branch1][C][=N][N][=C][Ring1][#Branch2][C][O]'},
#  {'text': '[C][=C][Branch1][Ring2][C][C][N][C][=C][C][=C][Branch1][C][N][C][=C][Ring1][#Branch1][O]'},
#  {'text': '[C][C][=Branch1][C][=O][C][C][=C][N][=C][C][Branch1][C][N][=C][Ring1][#Branch1][N]'},
#  {'text': '[C][C][Branch1][C][C][C][N][Branch1][#Branch1][C][C][=Branch1][C][=O][O][C][=Branch1][C][=N][N]'},
#  {'text': '[C][C][C][=C][Branch1][#Branch1][N][C][C][C][Ring1][Ring2][N][=C][Branch1][C][N][N][Ring1][#Branch2][C]'},
#  {'text': '[C][C][Branch1][C][C][Branch1][C][C][C][N][C][=C][C][Branch1][C][N][=N][Ring1][=Branch1]'},
#  {'text': '[C][C][C][=C][C][=C][C][Branch1][C][C][=C][Ring1][#Branch1][C][C][Branch1][C][C][=O]'}]

# %%
t = '{"text": "[C][C][N][C][C][C][Branch1][C][C][=C][Branch1][Ring1][C][C][C][=Branch1][C][=O][O]"}\n'

# %%
json.loads(t)['text']
# Out:
# '[C][C][N][C][C][C][Branch1][C][C][=C][Branch1][Ring1][C][C][C][=Branch1][C][=O][O]'
