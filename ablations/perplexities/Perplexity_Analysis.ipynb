# %%
import random
import json
import pandas as pd
import selfies as sf
from tqdm import tqdm
from rdkit import Chem
import matplotlib.pyplot as plt

# %%
def make_canonical_smiles(selfies):
    canon_smiles = None
    smiles = sf.decoder(selfies)

    try:
        canon_smiles = Chem.MolToSmiles(Chem.MolFromSmiles(smiles))
    except:
        pass  

    return canon_smiles

# %%
make_canonical_smiles("[C][O][C][=Branch1][C][=O][C][C][Branch1][C][C][N][C][C][C][=Branch1][C][=O][C][Ring1][=Branch1]")
# Out:
# 'COC(=O)CC(C)N1CCC(=O)C1'

# %% [markdown]
# ## Perplexities of Sas Selfies

# %%
gen_sas_df_aa = pd.read_csv("data-bin-gen-sas-selfies-aa-10K_ppl.csv", names=["ppl", "selfies"])
gen_sas_df_aa = gen_sas_df_aa.dropna()
gen_sas_df_aa["smiles"] = gen_sas_df_aa["selfies"].apply(make_canonical_smiles)
print("Lenght", len(gen_sas_df_aa))
gen_sas_df_aa.head()
# Out:
# Lenght 8841
#      ppl                                            selfies
# 0   1.79  [O][C][=C][C][=C][C][=C][Ring1][=Branch1][C][=...  \
# 1  19.22  [C][C][O][C][=Branch1][C][=O][N][C][C][N][Bran...
# 2  16.03  [C][O][C][C][N][Branch1][C][C][C][=C][C][=Bran...
# 3  39.30  [N][C][C][=C][C][C][C][Branch1][=Branch1][C][=...
# 4   6.23  [C][C][=N][N][=C][Branch1][Ring1][C][N][N][Rin...
#
#                                               smiles
# 0                               Oc1cccc2c1-c1nscc1-2
# 1  CCOC(=O)N1CCN(C)C(=O)C1Cc1scc(C(=O)O)c1N(C)COC...
# 2            COCCN(C)C=CC(=O)COCCOc1cc(COC(=O)CO)no1
# 3  NCC1=CCCC(C(=O)O)CCC1NC1=NC(CCOCC(=O)O)=C[SH]1...
# 4        Cc1nnc(CN)n1CC(C)(C)CCC(=O)c1cc(OC(C)C)cnn1

# %%
gen_sas_df = pd.read_csv("data-bin-gen-sas-selfies-10K_ppl.csv", names=["ppl", "selfies"])
gen_sas_df = gen_sas_df.dropna()
gen_sas_df["smiles"] = gen_sas_df["selfies"].apply(make_canonical_smiles)
print("Lenght", len(gen_sas_df))
gen_sas_df.head()
# Out:
# Lenght 4798
#     ppl                                            selfies
# 0  1.64  [C][O][C][=C][Branch1][Branch2][C][=C][C][=Bra...  \
# 1  1.63  [C][C][=C][C][=C][Branch1][=Branch2][N][C][=Br...
# 2  1.83  [C][C][Branch1][#Branch2][C][=N][O][C][C][C][C...
# 3  1.62  [C][C][=C][C][NH1][C][=Branch1][C][=O][C][=Bra...
# 4  1.61  [C][C][=Branch1][C][=O][C][=C][C][=C][Branch1]...
#
#                                               smiles
# 0   COC1=C(C=CC(=O)O)CCCC1O[SH](=O)(NO)C1(CN2CC2)CC1
# 1                              Cc1ccc(NC(=O)CC=O)cn1
# 2  CC(=N)n1cc(CCCC2CCC2=CCCCCCCOOC(=O)C(C)C=NOC2C...
# 3                      Cc1cc2[nH]c(=O)c(=O)[nH]c2cn1
# 4     CC(=O)c1ccc(C(=O)C=O)n1OCc1nc(CN)c(Cl)cc1N(C)C

# %%
gen_sas_df[gen_sas_df['smiles']=="COC(=O)CC(C)N1CCC(=O)C1"]
# Out:
# Empty DataFrame
# Columns: [ppl, selfies, smiles]
# Index: []

# %%
# non_gen_sas_df = pd.read_csv("data-bin-non-sas-selfies.csv", names=["ppl", "selfies"])
# non_gen_sas_df["smiles"] = non_gen_sas_df["selfies"].apply(make_canonical_smiles)
# print("Lenght", len(non_gen_sas_df))
# non_gen_sas_df.head()

# %%
# Check intersection
# set(gen_sas_df["smiles"].values).intersection(set(non_gen_sas_df["smiles"].values))

# %%
train_sas_df = pd.read_csv("data-bin-train-sas-all-selfies.csv", names=["ppl", "selfies"])
len(train_sas_df)
# Out:
# 454656

# %%
# train_sas_df["smiles"] = train_sas_df["selfies"].apply(make_canonical_smiles)
# print("Lenght", len(train_sas_df))
# train_sas_df.head()

# %%
train_smi_arr = []

for self in tqdm(train_sas_df["selfies"]):
    try:
        train_smi_arr.append(make_canonical_smiles(self))
    except:
        print("error")
    
# train_sas_df["smiles"] = train_sas_df["selfies"].apply(make_canonical_smiles)
# Out:
#  99%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊ | 450013/454656 [02:50<00:01, 3312.88it/s]
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
#  99%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████ | 451056/454656 [02:50<00:01, 3522.79it/s]
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
#  99%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎| 452065/454656 [02:50<00:00, 3556.68it/s]
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌| 452871/454656 [02:50<00:00, 3724.12it/s]
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊| 453847/454656 [02:51<00:00, 3964.15it/s]
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 454656/454656 [02:51<00:00, 2654.69it/s]
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error

# %%
train_sas_df_tr = train_sas_df[:452607]
train_sas_df_tr["smiles"] = train_smi_arr
# Out:
# /tmp/ipykernel_3078931/15569379.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_sas_df_tr["smiles"] = train_smi_arr

# %%
train_sas_df_tr.head()
# Out:
#     ppl                                            selfies
# 0  1.71  [O][C][C][C][C][N][Branch1][Branch2][C][=C][N]...  \
# 1  1.71  [C][C][=Branch1][C][=O][C][NH1][C][=C][N][=C][...
# 2  1.66  [N][C][C][C][N][Branch1][N][C][=Branch1][C][=O...
# 3  1.70  [C][=N][N][C][=Branch1][C][=O][C][C][C][O][C][...
# 4  1.80  [C][C][C][Branch1][Ring1][C][C][C][C][C][C][C]...
#
#                                               smiles
# 0          N#CC(=CC1CN(c2cncs2)CCC1CO)c1cccc(C=NO)c1
# 1     CCNC(=O)NN1CCC(=CNc2c(C(C)=O)[nH]c3cnccc23)CC1
# 2     COc1ccc(CC#CC2C(N)CCN2C(=O)c2cn[nH]c2)c(Cl)c1O
# 3             C=NNC(=O)CCCOCCNCCCc1cccc2nn(O)c(N)c12
# 4  CCC(CC)CCCCC=NNCCC=CCNc1c(N)c(C)nn1CCCCNn1c(C)...

# %%
# Check intersection
# len(set(train_sas_df["smiles"].values).intersection(set(non_gen_sas_df["smiles"].values)))

# %%
plt.figure(figsize=(10,8))

plt.hist(train_sas_df_tr['ppl'].values, alpha=0.5, density=False, range=[1.3,2.8], label="Train", bins=50)
plt.hist(gen_sas_df['ppl'].values[:10_000], alpha=0.5, density=False, range=[1.3,2.8], label="Generated 10K [Ours]", bins=50)
plt.hist(gen_sas_df_aa['ppl'].values[:10_000], alpha=0.5, density=False, range=[1.3,2.8], label="Generated 10K [Simple]", bins=50)

plt.xlabel("Perplexity")
plt.ylabel("Frequency (log)")
plt.yscale("log")
plt.title("Distributions of SAS PPL [bins=50]");
plt.legend(loc='upper right')

plt.show()

# %%
print(f"Generated Mean PPL {gen_sas_df['ppl'].mean():.2f}")
print(f"Not Generated Mean PPL {non_gen_sas_df['ppl'].mean():.2f}")
print(f"Train Mean PPL {train_sas_df['ppl'].mean():.2f}")

# %% [markdown]
# ## Perplexities of Aspirin

# %%
gen_aspirin_df = pd.read_csv("data-bin-gen-aspirin.csv", names=["ppl", "smiles"])
print("Lenght", len(gen_aspirin_df))
gen_aspirin_df.head()
# Out:
# Lenght 12288
#     ppl                                             smiles
# 0  1.54  COC(=O)C12CC1(O)C(=O)C(C)O2CC1=CC(O)C(=O)C1C1O...
# 1  1.56     C=C(C=CC=O)OC1C(=O)CC1CCC=C(CC(=O)O)C1CC1(C)OC
# 2  1.52   CC(C=O)=CC(C)(O)C(C=O)C=OC=C1C(=O)C2(C)OC1C2OC=O
# 3  1.52   C=CC1C=CC(O)C(=O)CC(=O)C1C#CC1C(O)C1C(C=O)=CCC=C
# 4  1.55    CC1=CCC(C2CC2C=O)OC1=OC=C(C=O)C1(C)C(=O)OC2CC21

# %%
non_gen_aspirin_df = pd.read_csv("data-bin-non-aspirin.csv", names=["ppl", "smiles"])
print("Lenght", len(non_gen_aspirin_df))
non_gen_aspirin_df.head()
# Out:
# Lenght 10240
#     ppl                                             smiles
# 0  1.51  O=CC1CC2CC2(C=O)C1C(=O)OO=CC(=O)C12CC3OC(C1)C3...
# 1  1.63         O=CC1(O)CCOC=C1OC1CC1CC(=O)OC1C=Cc2c1coc2C
# 2  1.51     CC=CCCC(=O)C1C(O)C1C=OCOC12OCC3CC1C(O)(C3)C2=O
# 3  1.61         CC(C(N)=O)c1ccsc1OC=OO=CC1C=CCC=C1C1COC1=O
# 4  1.54      CC=CC1CC(O)C(C)OC1=OC=C1COC(=O)C(O)C1C(C)(C)O

# %%
train_aspirin_df = pd.read_csv("data-bin-train-aspirin.csv", names=["ppl", "smiles"])
print("Lenght", len(train_aspirin_df))
train_aspirin_df.head()
# Out:
# Lenght 12288
#     ppl                                             smiles
# 0  1.61         CC(C=O)OC1CC(CO)CC1OC=c1oc(=C2COCO2)ccc1=O
# 1  1.54    C=C1C(C#N)OC(OC)C(=C)C1OC=C(C)C(OC)C1C(=O)CCC1O
# 2  1.53    CC(=CC=O)OC1C2OCC(=O)C21C=C(C)C1OC2C=CC(O2)C1=O
# 3  1.47  CC1(C)C(O)CC2C1C2(O)C(=O)OCC1CC1OC1C(C)C1(O)C(...
# 4  1.57       CC1C(=O)C2CCOC2C(C)C1OC#CC=COC(C)C1OC(C)C1=O

# %%
# Check intersection
set(gen_aspirin_df["smiles"].values).intersection(set(non_gen_aspirin_df["smiles"].values))
# Out:
# set()

# %%
# Check intersection
set(train_aspirin_df["smiles"].values).intersection(set(non_gen_aspirin_df["smiles"].values))
# Out:
# set()

# %%
plt.figure(figsize=(10,8))

plt.hist(train_aspirin_df['ppl'].values[:10_000], alpha=0.5, density=False, range=[1.3,2.2], label="Train", bins=50)
plt.hist(gen_aspirin_df['ppl'].values[:10_000], alpha=0.5, density=False, range=[1.3,2.2], label="Generated", bins=50)
plt.hist(non_gen_aspirin_df['ppl'].values[:10_000], alpha=0.5, density=False, range=[1.3,2.2], label="Not Generated", bins=50)

plt.xlabel("Perplexity")
plt.ylabel("Frequency (log)")
plt.yscale("log")
plt.title("Distributions of Aspirin PPL [bins=50]");
plt.legend(loc='upper right')

plt.show()

# %%
print(f"Generated Mean PPL {gen_aspirin_df['ppl'].mean():.2f}")
print(f"Not Generated Mean PPL {non_gen_aspirin_df['ppl'].mean():.2f}")
print(f"Train Mean PPL {train_aspirin_df['ppl'].mean():.2f}")
# Out:
# Generated Mean PPL 1.53
# Not Generated Mean PPL 1.58
# Train Mean PPL 1.56
