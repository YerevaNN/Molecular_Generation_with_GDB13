# %%
import re
import json

import pandas as pd
from rdkit import Chem
from tqdm import tqdm
import selfies as sf

# %%
def check_validness(smiles: str) -> bool:
    try:
        return Chem.MolFromSmiles(smiles) is not None
    except:
        return False


def check_canonical(smiles: str) -> bool:
    try:
        return get_canonical_form(smiles) == smiles
    except:
        return False
    

def get_canonical_form(smiles: str):
    try:
        return Chem.MolToSmiles(Chem.MolFromSmiles(smiles), canonical=True)
    except:
        print(f"Error while getting the canonical form for {smiles}.")
        return ""

# %%
path = f"OPT_1.2B_ep_1_half_rand_end_sf_848M_2.00E-04_hf_gradacc_32_iter_10000_from_valid.csv"

# %%
df = pd.read_json(path)
df = df[:10000]
df
# Out:
#                                                     seq  \
# 0     [Rand][C][Branch1][C][O][Branch1][Ring1][C][O]...
# 1     [Rand][C][=Branch1][C][=O][N][C][Branch1][C][C...
# 2     [Rand][C][Branch1][C][N][C][Branch1][C][O][C][...
# 3     [Rand][C][C][=C][C][Branch1][C][N][C][Ring1][=...
# 4     [Rand][N][#C][C][=C][Branch1][C][N][C][=C][C][...
# ...                                                 ...
# 9995  [Canon][C][O][C][=C][C][O][C][C][Ring1][Branch...
# 9996  [Canon][C][=C][C][C][Branch1][Branch1][C][O][R...
# 9997  [Canon][C][C][N][C][C][C][N][N][=C][Ring1][#Br...
# 9998  [Canon][C][C][C][C][C][N][C][C][Branch1][Branc...
# 9999  [Canon][C][C][=C][S][C][=C][Ring1][Branch1][C]...
#
#                                                  output
# 0     [C][Branch1][C][O][Branch1][Ring1][C][O][C][=B...
# 1     [C][=Branch1][C][=O][N][C][Branch1][C][C][C][R...
# 2     [C][Branch1][C][N][C][Branch1][C][O][C][C][Rin...
# 3     [C][C][=C][C][Branch1][C][N][C][Ring1][=Branch...
# 4     [N][#C][C][=C][Branch1][C][N][C][=C][C][Branch...
# ...                                                 ...
# 9995  [C][O][C][=C][C][O][C][C][Ring1][Branch1][Bran...
# 9996  [C][=C][C][C][Branch1][Branch1][C][O][Ring1][B...
# 9997  [C][C][N][C][C][C][N][N][=C][Ring1][#Branch1][...
# 9998  [C][C][C][C][C][N][C][C][Branch1][Branch2][C][...
# 9999  [C][C][=C][S][C][=C][Ring1][Branch1][C][C][=C]...
#
# [10000 rows x 2 columns]

# %%
df["tag"] = df["seq"].apply(lambda a: a[:a.index("]")+1])

# %%
def return_diff_seq(first_seq, second_seq):
    return second_seq[len(first_seq):]

# %%
df["seq"] = list(map(return_diff_seq, df["tag"], df["seq"]))

# %%
df
# Out:
#                                                     seq  \
# 0     [C][Branch1][C][O][Branch1][Ring1][C][O][C][=B...
# 1     [C][=Branch1][C][=O][N][C][Branch1][C][C][C][R...
# 2     [C][Branch1][C][N][C][Branch1][C][O][C][C][Rin...
# 3     [C][C][=C][C][Branch1][C][N][C][Ring1][=Branch...
# 4     [N][#C][C][=C][Branch1][C][N][C][=C][C][Branch...
# ...                                                 ...
# 9995  [C][O][C][=C][C][O][C][C][Ring1][Branch1][Bran...
# 9996  [C][=C][C][C][Branch1][Branch1][C][O][Ring1][B...
# 9997  [C][C][N][C][C][C][N][N][=C][Ring1][#Branch1][...
# 9998  [C][C][C][C][C][N][C][C][Branch1][Branch2][C][...
# 9999  [C][C][=C][S][C][=C][Ring1][Branch1][C][C][=C]...
#
#                                                  output      tag
# 0     [C][Branch1][C][O][Branch1][Ring1][C][O][C][=B...   [Rand]
# 1     [C][=Branch1][C][=O][N][C][Branch1][C][C][C][R...   [Rand]
# 2     [C][Branch1][C][N][C][Branch1][C][O][C][C][Rin...   [Rand]
# 3     [C][C][=C][C][Branch1][C][N][C][Ring1][=Branch...   [Rand]
# 4     [N][#C][C][=C][Branch1][C][N][C][=C][C][Branch...   [Rand]
# ...                                                 ...      ...
# 9995  [C][O][C][=C][C][O][C][C][Ring1][Branch1][Bran...  [Canon]
# 9996  [C][=C][C][C][Branch1][Branch1][C][O][Ring1][B...  [Canon]
# 9997  [C][C][N][C][C][C][N][N][=C][Ring1][#Branch1][...  [Canon]
# 9998  [C][C][C][C][C][N][C][C][Branch1][Branch2][C][...  [Canon]
# 9999  [C][C][=C][S][C][=C][Ring1][Branch1][C][C][=C]...  [Canon]
#
# [10000 rows x 3 columns]

# %%
df["diff"] = list(map(return_diff_seq, df["seq"], df["output"]))

# %%
df
# Out:
#                                                     seq  \
# 0     [C][Branch1][C][O][Branch1][Ring1][C][O][C][=B...
# 1     [C][=Branch1][C][=O][N][C][Branch1][C][C][C][R...
# 2     [C][Branch1][C][N][C][Branch1][C][O][C][C][Rin...
# 3     [C][C][=C][C][Branch1][C][N][C][Ring1][=Branch...
# 4     [N][#C][C][=C][Branch1][C][N][C][=C][C][Branch...
# ...                                                 ...
# 9995  [C][O][C][=C][C][O][C][C][Ring1][Branch1][Bran...
# 9996  [C][=C][C][C][Branch1][Branch1][C][O][Ring1][B...
# 9997  [C][C][N][C][C][C][N][N][=C][Ring1][#Branch1][...
# 9998  [C][C][C][C][C][N][C][C][Branch1][Branch2][C][...
# 9999  [C][C][=C][S][C][=C][Ring1][Branch1][C][C][=C]...
#
#                                                  output      tag     diff
# 0     [C][Branch1][C][O][Branch1][Ring1][C][O][C][=B...   [Rand]   [Rand]
# 1     [C][=Branch1][C][=O][N][C][Branch1][C][C][C][R...   [Rand]   [Rand]
# 2     [C][Branch1][C][N][C][Branch1][C][O][C][C][Rin...   [Rand]   [Rand]
# 3     [C][C][=C][C][Branch1][C][N][C][Ring1][=Branch...   [Rand]   [Rand]
# 4     [N][#C][C][=C][Branch1][C][N][C][=C][C][Branch...   [Rand]   [Rand]
# ...                                                 ...      ...      ...
# 9995  [C][O][C][=C][C][O][C][C][Ring1][Branch1][Bran...  [Canon]  [Canon]
# 9996  [C][=C][C][C][Branch1][Branch1][C][O][Ring1][B...  [Canon]  [Canon]
# 9997  [C][C][N][C][C][C][N][N][=C][Ring1][#Branch1][...  [Canon]  [Canon]
# 9998  [C][C][C][C][C][N][C][C][Branch1][Branch2][C][...  [Canon]  [Canon]
# 9999  [C][C][=C][S][C][=C][Ring1][Branch1][C][C][=C]...  [Canon]  [Canon]
#
# [10000 rows x 4 columns]

# %%
matched_df = df[df["diff"] == df["tag"]]
matched_df
# Out:
#                                                     seq  \
# 0     [C][Branch1][C][O][Branch1][Ring1][C][O][C][=B...
# 1     [C][=Branch1][C][=O][N][C][Branch1][C][C][C][R...
# 2     [C][Branch1][C][N][C][Branch1][C][O][C][C][Rin...
# 3     [C][C][=C][C][Branch1][C][N][C][Ring1][=Branch...
# 4     [N][#C][C][=C][Branch1][C][N][C][=C][C][Branch...
# ...                                                 ...
# 9995  [C][O][C][=C][C][O][C][C][Ring1][Branch1][Bran...
# 9996  [C][=C][C][C][Branch1][Branch1][C][O][Ring1][B...
# 9997  [C][C][N][C][C][C][N][N][=C][Ring1][#Branch1][...
# 9998  [C][C][C][C][C][N][C][C][Branch1][Branch2][C][...
# 9999  [C][C][=C][S][C][=C][Ring1][Branch1][C][C][=C]...
#
#                                                  output      tag     diff
# 0     [C][Branch1][C][O][Branch1][Ring1][C][O][C][=B...   [Rand]   [Rand]
# 1     [C][=Branch1][C][=O][N][C][Branch1][C][C][C][R...   [Rand]   [Rand]
# 2     [C][Branch1][C][N][C][Branch1][C][O][C][C][Rin...   [Rand]   [Rand]
# 3     [C][C][=C][C][Branch1][C][N][C][Ring1][=Branch...   [Rand]   [Rand]
# 4     [N][#C][C][=C][Branch1][C][N][C][=C][C][Branch...   [Rand]   [Rand]
# ...                                                 ...      ...      ...
# 9995  [C][O][C][=C][C][O][C][C][Ring1][Branch1][Bran...  [Canon]  [Canon]
# 9996  [C][=C][C][C][Branch1][Branch1][C][O][Ring1][B...  [Canon]  [Canon]
# 9997  [C][C][N][C][C][C][N][N][=C][Ring1][#Branch1][...  [Canon]  [Canon]
# 9998  [C][C][C][C][C][N][C][C][Branch1][Branch2][C][...  [Canon]  [Canon]
# 9999  [C][C][=C][S][C][=C][Ring1][Branch1][C][C][=C]...  [Canon]  [Canon]
#
# [8529 rows x 4 columns]

# %%
matched_rand = len(matched_df[matched_df["tag"]=="[Rand]"])
matched_rand
# Out:
# 4208

# %%
matched_canon = len(matched_df[matched_df["tag"]=="[Canon]"])
matched_canon
# Out:
# 4321

# %%
mismatched_df = df[df["diff"] != df["tag"]]
mismatched_df
# Out:
#                                                     seq  \
# 8     [C][=Branch1][N][=C][N][=C][N][N][=C][Branch1]...
# 20    [C][C][Branch1][C][O][C][Branch1][Ring1][C][O]...
# 21    [C][Branch1][N][C][=C][C][C][N][C][Ring1][#Bra...
# 23    [C][N][C][Ring1][Ring1][C][C][Branch1][=Branch...
# 31    [N][C][=C][C][=Branch1][C][=O][N][C][C][N][Bra...
# ...                                                 ...
# 9952  [C][#C][C][C][C][C][Branch1][C][N][C][C][C][Ri...
# 9956  [C][C][C][C][O][C][C][C][=Branch1][C][=N][N][B...
# 9970  [C][C][C][C][C][Ring1][Ring2][C][=Branch1][C][...
# 9973  [C][=C][C][C][C][N][C][Ring1][Branch1][C][Ring...
# 9987  [C][C][Branch1][C][O][Branch1][Ring1][C][#N][C...
#
#                                                  output      tag  \
# 8     [C][=Branch1][N][=C][N][=C][N][N][=C][Branch1]...   [Rand]
# 20    [C][C][Branch1][C][O][C][Branch1][Ring1][C][O]...   [Rand]
# 21    [C][Branch1][N][C][=C][C][C][N][C][Ring1][#Bra...   [Rand]
# 23    [C][N][C][Ring1][Ring1][C][C][Branch1][=Branch...   [Rand]
# 31    [N][C][=C][C][=Branch1][C][=O][N][C][C][N][Bra...   [Rand]
# ...                                                 ...      ...
# 9952  [C][#C][C][C][C][C][Branch1][C][N][C][C][C][Ri...  [Canon]
# 9956  [C][C][C][C][O][C][C][C][=Branch1][C][=N][N][B...  [Canon]
# 9970  [C][C][C][C][C][Ring1][Ring2][C][=Branch1][C][...  [Canon]
# 9973  [C][=C][C][C][C][N][C][Ring1][Branch1][C][Ring...  [Canon]
# 9987  [C][C][Branch1][C][O][Branch1][Ring1][C][#N][C...  [Canon]
#
#                          diff
# 8                   [C][Rand]
# 20          [Ring1][=N][Rand]
# 21     [Ring1][Branch1][Rand]
# 23                  [C][Rand]
# 31           [Ring1][N][Rand]
# ...                       ...
# 9952               [C][Canon]
# 9956               [C][Canon]
# 9970              [=O][Canon]
# 9973        [Ring1][O][Canon]
# 9987  [Ring1][Branch2][Canon]
#
# [1471 rows x 4 columns]

# %%
def contains_fn(tag, diff_seq):
    return tag in diff_seq

# %%
mismatched_df[list(map(contains_fn, mismatched_df["tag"], mismatched_df["diff"]))]
# Out:
#                                                     seq  \
# 8     [C][=Branch1][N][=C][N][=C][N][N][=C][Branch1]...
# 20    [C][C][Branch1][C][O][C][Branch1][Ring1][C][O]...
# 21    [C][Branch1][N][C][=C][C][C][N][C][Ring1][#Bra...
# 23    [C][N][C][Ring1][Ring1][C][C][Branch1][=Branch...
# 31    [N][C][=C][C][=Branch1][C][=O][N][C][C][N][Bra...
# ...                                                 ...
# 9952  [C][#C][C][C][C][C][Branch1][C][N][C][C][C][Ri...
# 9956  [C][C][C][C][O][C][C][C][=Branch1][C][=N][N][B...
# 9970  [C][C][C][C][C][Ring1][Ring2][C][=Branch1][C][...
# 9973  [C][=C][C][C][C][N][C][Ring1][Branch1][C][Ring...
# 9987  [C][C][Branch1][C][O][Branch1][Ring1][C][#N][C...
#
#                                                  output      tag  \
# 8     [C][=Branch1][N][=C][N][=C][N][N][=C][Branch1]...   [Rand]
# 20    [C][C][Branch1][C][O][C][Branch1][Ring1][C][O]...   [Rand]
# 21    [C][Branch1][N][C][=C][C][C][N][C][Ring1][#Bra...   [Rand]
# 23    [C][N][C][Ring1][Ring1][C][C][Branch1][=Branch...   [Rand]
# 31    [N][C][=C][C][=Branch1][C][=O][N][C][C][N][Bra...   [Rand]
# ...                                                 ...      ...
# 9952  [C][#C][C][C][C][C][Branch1][C][N][C][C][C][Ri...  [Canon]
# 9956  [C][C][C][C][O][C][C][C][=Branch1][C][=N][N][B...  [Canon]
# 9970  [C][C][C][C][C][Ring1][Ring2][C][=Branch1][C][...  [Canon]
# 9973  [C][=C][C][C][C][N][C][Ring1][Branch1][C][Ring...  [Canon]
# 9987  [C][C][Branch1][C][O][Branch1][Ring1][C][#N][C...  [Canon]
#
#                          diff
# 8                   [C][Rand]
# 20          [Ring1][=N][Rand]
# 21     [Ring1][Branch1][Rand]
# 23                  [C][Rand]
# 31           [Ring1][N][Rand]
# ...                       ...
# 9952               [C][Canon]
# 9956               [C][Canon]
# 9970              [=O][Canon]
# 9973        [Ring1][O][Canon]
# 9987  [Ring1][Branch2][Canon]
#
# [1343 rows x 4 columns]

# %%
# Rows that didn't contain the ground truth tag
mismatched_df[[not el for el in list(map(contains_fn, mismatched_df["tag"], mismatched_df["diff"]))]]
# Out:
#                                                     seq  \
# 154   [C][C][C][O][C][C][C][C][N][Branch1][Ring2][C]...
# 297   [C][C][C][C][C][Branch1][Branch2][C][=N][C][=N...
# 364   [C][N][C][Branch1][N][C][=N][O][C][Branch1][Ri...
# 454   [C][=C][O][C][C][=C][Branch1][C][O][N][Branch1...
# 765   [C][O][C][C][C][C][Branch1][Ring2][O][C][=O][C...
# ...                                                 ...
# 9488  [C][=C][C][=C][C][=Branch1][Branch2][=N][N][=C...
# 9534  [C][C][=Branch1][Ring1][=N][O][C][C][Branch1][...
# 9559  [C][=C][C][=Branch1][C][=O][NH1][N][Branch1][=...
# 9585  [C][C][C][C][N][Ring1][Ring1][C][C][Ring1][=Br...
# 9615  [C][C][C][Branch1][C][C][N][Ring1][Ring2][C][C...
#
#                                                  output      tag  \
# 154   [C][C][C][O][C][C][C][C][N][Branch1][Ring2][C]...   [Rand]
# 297   [C][C][C][C][C][Branch1][Branch2][C][=N][C][=N...   [Rand]
# 364   [C][N][C][Branch1][N][C][=N][O][C][Branch1][Ri...   [Rand]
# 454   [C][=C][O][C][C][=C][Branch1][C][O][N][Branch1...   [Rand]
# 765   [C][O][C][C][C][C][Branch1][Ring2][O][C][=O][C...   [Rand]
# ...                                                 ...      ...
# 9488  [C][=C][C][=C][C][=Branch1][Branch2][=N][N][=C...  [Canon]
# 9534  [C][C][=Branch1][Ring1][=N][O][C][C][Branch1][...  [Canon]
# 9559  [C][=C][C][=Branch1][C][=O][NH1][N][Branch1][=...  [Canon]
# 9585  [C][C][C][C][N][Ring1][Ring1][C][C][Ring1][=Br...  [Canon]
# 9615  [C][C][C][Branch1][C][C][N][Ring1][Ring2][C][C...  [Canon]
#
#                               diff
# 154   [Ring1][=N][Ring1][N][Canon]
# 297                        [Canon]
# 364           [C][Ring1][O][Canon]
# 454                        [Canon]
# 765    [Ring1][#Branch2][C][Canon]
# ...                            ...
# 9488                        [Rand]
# 9534             [Ring1][=N][Rand]
# 9559                        [Rand]
# 9585                        [Rand]
# 9615                        [Rand]
#
# [128 rows x 4 columns]
