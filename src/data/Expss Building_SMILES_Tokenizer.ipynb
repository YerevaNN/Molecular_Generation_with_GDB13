# %%
import os
import json
from collections import OrderedDict

# %% [markdown]
# ### Steps
#
# 1. **Download** vocab.json from [here](https://huggingface.co/DeepChem/SmilesTokenizer_PubChem_1M/tree/main)
# 2. place in `/data-bin/tokenizers/tokenizer_smiles` folder
# 3. rename to `vocab_deepchem.json`

# %%
os.chdir("./tokenizers/tokenizer_smiles")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 os.chdir("./tokenizers/tokenizer_smiles")
#
# FileNotFoundError: [Errno 2] No such file or directory: './tokenizers/tokenizer_smiles'

# %%
with open("./deepchem_vocab.json", "r") as f:
    vocab = json.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 with open("./deepchem_vocab.json", "r") as f:
#       2     vocab = json.load(f)
#
# File ~/miniconda3/envs/molgen/lib/python3.11/site-packages/IPython/core/interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: './deepchem_vocab.json'

# %%
vocab_tokens = [t for t in vocab.keys()]

print(len(vocab_tokens))
# Out:
# 591

# %%
vocab_tokens
# Out:
# ['[PAD]',
#  '[unused1]',
#  '[unused2]',
#  '[unused3]',
#  '[unused4]',
#  '[unused5]',
#  '[unused6]',
#  '[unused7]',
#  '[unused8]',
#  '[unused9]',
#  '[unused10]',
#  '[UNK]',
#  '[CLS]',
#  '[SEP]',
#  '[MASK]',
#  'c',
#  'C',
#  '(',
#  ')',
#  'O',
#  '1',
#  '2',
#  '=',
#  'N',
#  '.',
#  'n',
#  '3',
#  'F',
#  'Cl',
#  '>>',
#  '~',
#  '-',
#  '4',
#  '[C@H]',
#  'S',
#  '[C@@H]',
#  '[O-]',
#  'Br',
#  '#',
#  '/',
#  '[nH]',
#  '[N+]',
#  's',
#  '5',
#  'o',
#  'P',
#  '[Na+]',
#  '[Si]',
#  'I',
#  '[Na]',
#  '[Pd]',
#  '[K+]',
#  '[K]',
#  '[P]',
#  'B',
#  '[C@]',
#  '[C@@]',
#  '[Cl-]',
#  '6',
#  '[OH-]',
#  '\\',
#  '[N-]',
#  '[Li]',
#  '[H]',
#  '[2H]',
#  '[NH4+]',
#  '[c-]',
#  '[P-]',
#  '[Cs+]',
#  '[Li+]',
#  '[Cs]',
#  '[NaH]',
#  '[H-]',
#  '[O+]',
#  '[BH4-]',
#  '[Cu]',
#  '7',
#  '[Mg]',
#  '[Fe+2]',
#  '[n+]',
#  '[Sn]',
#  '[BH-]',
#  '[Pd+2]',
#  '[CH]',
#  '[I-]',
#  '[Br-]',
#  '[C-]',
#  '[Zn]',
#  '[B-]',
#  '[F-]',
#  '[Al]',
#  '[P+]',
#  '[BH3-]',
#  '[Fe]',
#  '[C]',
#  '[AlH4]',
#  '[Ni]',
#  '[SiH]',
#  '8',
#  '[Cu+2]',
#  '[Mn]',
#  '[AlH]',
#  '[nH+]',
#  '[AlH4-]',
#  '[O-2]',
#  '[Cr]',
#  '[Mg+2]',
#  '[NH3+]',
#  '[S@]',
#  '[Pt]',
#  '[Al+3]',
#  '[S@@]',
#  '[S-]',
#  '[Ti]',
#  '[Zn+2]',
#  '[PH]',
#  '[NH2+]',
#  '[Ru]',
#  '[Ag+]',
#  '[S+]',
#  '[I+3]',
#  '[NH+]',
#  '[Ca+2]',
#  '[Ag]',
#  '9',
#  '[Os]',
#  '[Se]',
#  '[SiH2]',
#  '[Ca]',
#  '[Ti+4]',
#  '[Ac]',
#  '[Cu+]',
#  '[S]',
#  '[Rh]',
#  '[Cl+3]',
#  '[cH-]',
#  '[Zn+]',
#  '[O]',
#  '[Cl+]',
#  '[SH]',
#  '[H+]',
#  '[Pd+]',
#  '[se]',
#  '[PH+]',
#  '[I]',
#  '[Pt+2]',
#  '[C+]',
#  '[Mg+]',
#  '[Hg]',
#  '[W]',
#  '[SnH]',
#  '[SiH3]',
#  '[Fe+3]',
#  '[NH]',
#  '[Mo]',
#  '[CH2+]',
#  '%10',
#  '[CH2-]',
#  '[CH2]',
#  '[n-]',
#  '[Ce+4]',
#  '[NH-]',
#  '[Co]',
#  '[I+]',
#  '[PH2]',
#  '[Pt+4]',
#  '[Ce]',
#  '[B]',
#  '[Sn+2]',
#  '[Ba+2]',
#  '%11',
#  '[Fe-3]',
#  '[18F]',
#  '[SH-]',
#  '[Pb+2]',
#  '[Os-2]',
#  '[Zr+4]',
#  '[N]',
#  '[Ir]',
#  '[Bi]',
#  '[Ni+2]',
#  '[P@]',
#  '[Co+2]',
#  '[s+]',
#  '[As]',
#  '[P+3]',
#  '[Hg+2]',
#  '[Yb+3]',
#  '[CH-]',
#  '[Zr+2]',
#  '[Mn+2]',
#  '[CH+]',
#  '[In]',
#  '[KH]',
#  '[Ce+3]',
#  '[Zr]',
#  '[AlH2-]',
#  '[OH2+]',
#  '[Ti+3]',
#  '[Rh+2]',
#  '[Sb]',
#  '[S-2]',
#  '%12',
#  '[P@@]',
#  '[Si@H]',
#  '[Mn+4]',
#  'p',
#  '[Ba]',
#  '[NH2-]',
#  '[Ge]',
#  '[Pb+4]',
#  '[Cr+3]',
#  '[Au]',
#  '[LiH]',
#  '[Sc+3]',
#  '[o+]',
#  '[Rh-3]',
#  '%13',
#  '[Br]',
#  '[Sb-]',
#  '[S@+]',
#  '[I+2]',
#  '[Ar]',
#  '[V]',
#  '[Cu-]',
#  '[Al-]',
#  '[Te]',
#  '[13c]',
#  '[13C]',
#  '[Cl]',
#  '[PH4+]',
#  '[SiH4]',
#  '[te]',
#  '[CH3-]',
#  '[S@@+]',
#  '[Rh+3]',
#  '[SH+]',
#  '[Bi+3]',
#  '[Br+2]',
#  '[La]',
#  '[La+3]',
#  '[Pt-2]',
#  '[N@@]',
#  '[PH3+]',
#  '[N@]',
#  '[Si+4]',
#  '[Sr+2]',
#  '[Al+]',
#  '[Pb]',
#  '[SeH]',
#  '[Si-]',
#  '[V+5]',
#  '[Y+3]',
#  '[Re]',
#  '[Ru+]',
#  '[Sm]',
#  '*',
#  '[3H]',
#  '[NH2]',
#  '[Ag-]',
#  '[13CH3]',
#  '[OH+]',
#  '[Ru+3]',
#  '[OH]',
#  '[Gd+3]',
#  '[13CH2]',
#  '[In+3]',
#  '[Si@@]',
#  '[Si@]',
#  '[Ti+2]',
#  '[Sn+]',
#  '[Cl+2]',
#  '[AlH-]',
#  '[Pd-2]',
#  '[SnH3]',
#  '[B+3]',
#  '[Cu-2]',
#  '[Nd+3]',
#  '[Pb+3]',
#  '[13cH]',
#  '[Fe-4]',
#  '[Ga]',
#  '[Sn+4]',
#  '[Hg+]',
#  '[11CH3]',
#  '[Hf]',
#  '[Pr]',
#  '[Y]',
#  '[S+2]',
#  '[Cd]',
#  '[Cr+6]',
#  '[Zr+3]',
#  '[Rh+]',
#  '[CH3]',
#  '[N-3]',
#  '[Hf+2]',
#  '[Th]',
#  '[Sb+3]',
#  '%14',
#  '[Cr+2]',
#  '[Ru+2]',
#  '[Hf+4]',
#  '[14C]',
#  '[Ta]',
#  '[Tl+]',
#  '[B+]',
#  '[Os+4]',
#  '[PdH2]',
#  '[Pd-]',
#  '[Cd+2]',
#  '[Co+3]',
#  '[S+4]',
#  '[Nb+5]',
#  '[123I]',
#  '[c+]',
#  '[Rb+]',
#  '[V+2]',
#  '[CH3+]',
#  '[Ag+2]',
#  '[cH+]',
#  '[Mn+3]',
#  '[Se-]',
#  '[As-]',
#  '[Eu+3]',
#  '[SH2]',
#  '[Sm+3]',
#  '[IH+]',
#  '%15',
#  '[OH3+]',
#  '[PH3]',
#  '[IH2+]',
#  '[SH2+]',
#  '[Ir+3]',
#  '[AlH3]',
#  '[Sc]',
#  '[Yb]',
#  '[15NH2]',
#  '[Lu]',
#  '[sH+]',
#  '[Gd]',
#  '[18F-]',
#  '[SH3+]',
#  '[SnH4]',
#  '[TeH]',
#  '[Si@@H]',
#  '[Ga+3]',
#  '[CaH2]',
#  '[Tl]',
#  '[Ta+5]',
#  '[GeH]',
#  '[Br+]',
#  '[Sr]',
#  '[Tl+3]',
#  '[Sm+2]',
#  '[PH5]',
#  '%16',
#  '[N@@+]',
#  '[Au+3]',
#  '[C-4]',
#  '[Nd]',
#  '[Ti+]',
#  '[IH]',
#  '[N@+]',
#  '[125I]',
#  '[Eu]',
#  '[Sn+3]',
#  '[Nb]',
#  '[Er+3]',
#  '[123I-]',
#  '[14c]',
#  '%17',
#  '[SnH2]',
#  '[YH]',
#  '[Sb+5]',
#  '[Pr+3]',
#  '[Ir+]',
#  '[N+3]',
#  '[AlH2]',
#  '[19F]',
#  '%18',
#  '[Tb]',
#  '[14CH]',
#  '[Mo+4]',
#  '[Si+]',
#  '[BH]',
#  '[Be]',
#  '[Rb]',
#  '[pH]',
#  '%19',
#  '%20',
#  '[Xe]',
#  '[Ir-]',
#  '[Be+2]',
#  '[C+4]',
#  '[RuH2]',
#  '[15NH]',
#  '[U+2]',
#  '[Au-]',
#  '%21',
#  '%22',
#  '[Au+]',
#  '[15n]',
#  '[Al+2]',
#  '[Tb+3]',
#  '[15N]',
#  '[V+3]',
#  '[W+6]',
#  '[14CH3]',
#  '[Cr+4]',
#  '[ClH+]',
#  'b',
#  '[Ti+6]',
#  '[Nd+]',
#  '[Zr+]',
#  '[PH2+]',
#  '[Fm]',
#  '[N@H+]',
#  '[RuH]',
#  '[Dy+3]',
#  '%23',
#  '[Hf+3]',
#  '[W+4]',
#  '[11C]',
#  '[13CH]',
#  '[Er]',
#  '[124I]',
#  '[LaH]',
#  '[F]',
#  '[siH]',
#  '[Ga+]',
#  '[Cm]',
#  '[GeH3]',
#  '[IH-]',
#  '[U+6]',
#  '[SeH+]',
#  '[32P]',
#  '[SeH-]',
#  '[Pt-]',
#  '[Ir+2]',
#  '[se+]',
#  '[U]',
#  '[F+]',
#  '[BH2]',
#  '[As+]',
#  '[Cf]',
#  '[ClH2+]',
#  '[Ni+]',
#  '[TeH3]',
#  '[SbH2]',
#  '[Ag+3]',
#  '%24',
#  '[18O]',
#  '[PH4]',
#  '[Os+2]',
#  '[Na-]',
#  '[Sb+2]',
#  '[V+4]',
#  '[Ho+3]',
#  '[68Ga]',
#  '[PH-]',
#  '[Bi+2]',
#  '[Ce+2]',
#  '[Pd+3]',
#  '[99Tc]',
#  '[13C@@H]',
#  '[Fe+6]',
#  '[c]',
#  '[GeH2]',
#  '[10B]',
#  '[Cu+3]',
#  '[Mo+2]',
#  '[Cr+]',
#  '[Pd+4]',
#  '[Dy]',
#  '[AsH]',
#  '[Ba+]',
#  '[SeH2]',
#  '[In+]',
#  '[TeH2]',
#  '[BrH+]',
#  '[14cH]',
#  '[W+]',
#  '[13C@H]',
#  '[AsH2]',
#  '[In+2]',
#  '[N+2]',
#  '[N@@H+]',
#  '[SbH]',
#  '[60Co]',
#  '[AsH4+]',
#  '[AsH3]',
#  '[18OH]',
#  '[Ru-2]',
#  '[Na-2]',
#  '[CuH2]',
#  '[31P]',
#  '[Ti+5]',
#  '[35S]',
#  '[P@@H]',
#  '[ArH]',
#  '[Co+]',
#  '[Zr-2]',
#  '[BH2-]',
#  '[131I]',
#  '[SH5]',
#  '[VH]',
#  '[B+2]',
#  '[Yb+2]',
#  '[14C@H]',
#  '[211At]',
#  '[NH3+2]',
#  '[IrH]',
#  '[IrH2]',
#  '[Rh-]',
#  '[Cr-]',
#  '[Sb+]',
#  '[Ni+3]',
#  '[TaH3]',
#  '[Tl+2]',
#  '[64Cu]',
#  '[Tc]',
#  '[Cd+]',
#  '[1H]',
#  '[15nH]',
#  '[AlH2+]',
#  '[FH+2]',
#  '[BiH3]',
#  '[Ru-]',
#  '[Mo+6]',
#  '[AsH+]',
#  '[BaH2]',
#  '[BaH]',
#  '[Fe+4]',
#  '[229Th]',
#  '[Th+4]',
#  '[As+3]',
#  '[NH+3]',
#  '[P@H]',
#  '[Li-]',
#  '[7NaH]',
#  '[Bi+]',
#  '[PtH+2]',
#  '[p-]',
#  '[Re+5]',
#  '[NiH]',
#  '[Ni-]',
#  '[Xe+]',
#  '[Ca+]',
#  '[11c]',
#  '[Rh+4]',
#  '[AcH]',
#  '[HeH]',
#  '[Sc+2]',
#  '[Mn+]',
#  '[UH]',
#  '[14CH2]',
#  '[SiH4+]',
#  '[18OH2]',
#  '[Ac-]',
#  '[Re+4]',
#  '[118Sn]',
#  '[153Sm]',
#  '[P+2]',
#  '[9CH]',
#  '[9CH3]',
#  '[Y-]',
#  '[NiH2]',
#  '[Si+2]',
#  '[Mn+6]',
#  '[ZrH2]',
#  '[C-2]',
#  '[Bi+5]',
#  '[24NaH]',
#  '[Fr]',
#  '[15CH]',
#  '[Se+]',
#  '[At]',
#  '[P-3]',
#  '[124I-]',
#  '[CuH2-]',
#  '[Nb+4]',
#  '[Nb+3]',
#  '[MgH]',
#  '[Ir+4]',
#  '[67Ga+3]',
#  '[67Ga]',
#  '[13N]',
#  '[15OH2]',
#  '[2NH]',
#  '[Ho]',
#  '[Cn]']

# %%
# define special tokens, order is important!
special_tokens = [
    "<s>",
    "[PAD]",
    "</s>",
    "[UNK]",
    "[SEP]",
    "[CLS]",
    "[MASK]",
    "[unused1]",
    "[unused2]",
    "[unused3]",
    "[unused4]",
    "[unused5]",
    "[unused6]",
    "[unused7]",
    "[unused8]",
    "[unused9]",
    "[unused10]"
]

# %%
# find special tokens in vocab and remove
vocab_tokens[:15]
# Out:
# ['[PAD]',
#  '[unused1]',
#  '[unused2]',
#  '[unused3]',
#  '[unused4]',
#  '[unused5]',
#  '[unused6]',
#  '[unused7]',
#  '[unused8]',
#  '[unused9]',
#  '[unused10]',
#  '[UNK]',
#  '[CLS]',
#  '[SEP]',
#  '[MASK]']

# %%
filtered_vocab_tokens = vocab_tokens[15:]
filtered_vocab_tokens
# Out:
# ['c',
#  'C',
#  '(',
#  ')',
#  'O',
#  '1',
#  '2',
#  '=',
#  'N',
#  '.',
#  'n',
#  '3',
#  'F',
#  'Cl',
#  '>>',
#  '~',
#  '-',
#  '4',
#  '[C@H]',
#  'S',
#  '[C@@H]',
#  '[O-]',
#  'Br',
#  '#',
#  '/',
#  '[nH]',
#  '[N+]',
#  's',
#  '5',
#  'o',
#  'P',
#  '[Na+]',
#  '[Si]',
#  'I',
#  '[Na]',
#  '[Pd]',
#  '[K+]',
#  '[K]',
#  '[P]',
#  'B',
#  '[C@]',
#  '[C@@]',
#  '[Cl-]',
#  '6',
#  '[OH-]',
#  '\\',
#  '[N-]',
#  '[Li]',
#  '[H]',
#  '[2H]',
#  '[NH4+]',
#  '[c-]',
#  '[P-]',
#  '[Cs+]',
#  '[Li+]',
#  '[Cs]',
#  '[NaH]',
#  '[H-]',
#  '[O+]',
#  '[BH4-]',
#  '[Cu]',
#  '7',
#  '[Mg]',
#  '[Fe+2]',
#  '[n+]',
#  '[Sn]',
#  '[BH-]',
#  '[Pd+2]',
#  '[CH]',
#  '[I-]',
#  '[Br-]',
#  '[C-]',
#  '[Zn]',
#  '[B-]',
#  '[F-]',
#  '[Al]',
#  '[P+]',
#  '[BH3-]',
#  '[Fe]',
#  '[C]',
#  '[AlH4]',
#  '[Ni]',
#  '[SiH]',
#  '8',
#  '[Cu+2]',
#  '[Mn]',
#  '[AlH]',
#  '[nH+]',
#  '[AlH4-]',
#  '[O-2]',
#  '[Cr]',
#  '[Mg+2]',
#  '[NH3+]',
#  '[S@]',
#  '[Pt]',
#  '[Al+3]',
#  '[S@@]',
#  '[S-]',
#  '[Ti]',
#  '[Zn+2]',
#  '[PH]',
#  '[NH2+]',
#  '[Ru]',
#  '[Ag+]',
#  '[S+]',
#  '[I+3]',
#  '[NH+]',
#  '[Ca+2]',
#  '[Ag]',
#  '9',
#  '[Os]',
#  '[Se]',
#  '[SiH2]',
#  '[Ca]',
#  '[Ti+4]',
#  '[Ac]',
#  '[Cu+]',
#  '[S]',
#  '[Rh]',
#  '[Cl+3]',
#  '[cH-]',
#  '[Zn+]',
#  '[O]',
#  '[Cl+]',
#  '[SH]',
#  '[H+]',
#  '[Pd+]',
#  '[se]',
#  '[PH+]',
#  '[I]',
#  '[Pt+2]',
#  '[C+]',
#  '[Mg+]',
#  '[Hg]',
#  '[W]',
#  '[SnH]',
#  '[SiH3]',
#  '[Fe+3]',
#  '[NH]',
#  '[Mo]',
#  '[CH2+]',
#  '%10',
#  '[CH2-]',
#  '[CH2]',
#  '[n-]',
#  '[Ce+4]',
#  '[NH-]',
#  '[Co]',
#  '[I+]',
#  '[PH2]',
#  '[Pt+4]',
#  '[Ce]',
#  '[B]',
#  '[Sn+2]',
#  '[Ba+2]',
#  '%11',
#  '[Fe-3]',
#  '[18F]',
#  '[SH-]',
#  '[Pb+2]',
#  '[Os-2]',
#  '[Zr+4]',
#  '[N]',
#  '[Ir]',
#  '[Bi]',
#  '[Ni+2]',
#  '[P@]',
#  '[Co+2]',
#  '[s+]',
#  '[As]',
#  '[P+3]',
#  '[Hg+2]',
#  '[Yb+3]',
#  '[CH-]',
#  '[Zr+2]',
#  '[Mn+2]',
#  '[CH+]',
#  '[In]',
#  '[KH]',
#  '[Ce+3]',
#  '[Zr]',
#  '[AlH2-]',
#  '[OH2+]',
#  '[Ti+3]',
#  '[Rh+2]',
#  '[Sb]',
#  '[S-2]',
#  '%12',
#  '[P@@]',
#  '[Si@H]',
#  '[Mn+4]',
#  'p',
#  '[Ba]',
#  '[NH2-]',
#  '[Ge]',
#  '[Pb+4]',
#  '[Cr+3]',
#  '[Au]',
#  '[LiH]',
#  '[Sc+3]',
#  '[o+]',
#  '[Rh-3]',
#  '%13',
#  '[Br]',
#  '[Sb-]',
#  '[S@+]',
#  '[I+2]',
#  '[Ar]',
#  '[V]',
#  '[Cu-]',
#  '[Al-]',
#  '[Te]',
#  '[13c]',
#  '[13C]',
#  '[Cl]',
#  '[PH4+]',
#  '[SiH4]',
#  '[te]',
#  '[CH3-]',
#  '[S@@+]',
#  '[Rh+3]',
#  '[SH+]',
#  '[Bi+3]',
#  '[Br+2]',
#  '[La]',
#  '[La+3]',
#  '[Pt-2]',
#  '[N@@]',
#  '[PH3+]',
#  '[N@]',
#  '[Si+4]',
#  '[Sr+2]',
#  '[Al+]',
#  '[Pb]',
#  '[SeH]',
#  '[Si-]',
#  '[V+5]',
#  '[Y+3]',
#  '[Re]',
#  '[Ru+]',
#  '[Sm]',
#  '*',
#  '[3H]',
#  '[NH2]',
#  '[Ag-]',
#  '[13CH3]',
#  '[OH+]',
#  '[Ru+3]',
#  '[OH]',
#  '[Gd+3]',
#  '[13CH2]',
#  '[In+3]',
#  '[Si@@]',
#  '[Si@]',
#  '[Ti+2]',
#  '[Sn+]',
#  '[Cl+2]',
#  '[AlH-]',
#  '[Pd-2]',
#  '[SnH3]',
#  '[B+3]',
#  '[Cu-2]',
#  '[Nd+3]',
#  '[Pb+3]',
#  '[13cH]',
#  '[Fe-4]',
#  '[Ga]',
#  '[Sn+4]',
#  '[Hg+]',
#  '[11CH3]',
#  '[Hf]',
#  '[Pr]',
#  '[Y]',
#  '[S+2]',
#  '[Cd]',
#  '[Cr+6]',
#  '[Zr+3]',
#  '[Rh+]',
#  '[CH3]',
#  '[N-3]',
#  '[Hf+2]',
#  '[Th]',
#  '[Sb+3]',
#  '%14',
#  '[Cr+2]',
#  '[Ru+2]',
#  '[Hf+4]',
#  '[14C]',
#  '[Ta]',
#  '[Tl+]',
#  '[B+]',
#  '[Os+4]',
#  '[PdH2]',
#  '[Pd-]',
#  '[Cd+2]',
#  '[Co+3]',
#  '[S+4]',
#  '[Nb+5]',
#  '[123I]',
#  '[c+]',
#  '[Rb+]',
#  '[V+2]',
#  '[CH3+]',
#  '[Ag+2]',
#  '[cH+]',
#  '[Mn+3]',
#  '[Se-]',
#  '[As-]',
#  '[Eu+3]',
#  '[SH2]',
#  '[Sm+3]',
#  '[IH+]',
#  '%15',
#  '[OH3+]',
#  '[PH3]',
#  '[IH2+]',
#  '[SH2+]',
#  '[Ir+3]',
#  '[AlH3]',
#  '[Sc]',
#  '[Yb]',
#  '[15NH2]',
#  '[Lu]',
#  '[sH+]',
#  '[Gd]',
#  '[18F-]',
#  '[SH3+]',
#  '[SnH4]',
#  '[TeH]',
#  '[Si@@H]',
#  '[Ga+3]',
#  '[CaH2]',
#  '[Tl]',
#  '[Ta+5]',
#  '[GeH]',
#  '[Br+]',
#  '[Sr]',
#  '[Tl+3]',
#  '[Sm+2]',
#  '[PH5]',
#  '%16',
#  '[N@@+]',
#  '[Au+3]',
#  '[C-4]',
#  '[Nd]',
#  '[Ti+]',
#  '[IH]',
#  '[N@+]',
#  '[125I]',
#  '[Eu]',
#  '[Sn+3]',
#  '[Nb]',
#  '[Er+3]',
#  '[123I-]',
#  '[14c]',
#  '%17',
#  '[SnH2]',
#  '[YH]',
#  '[Sb+5]',
#  '[Pr+3]',
#  '[Ir+]',
#  '[N+3]',
#  '[AlH2]',
#  '[19F]',
#  '%18',
#  '[Tb]',
#  '[14CH]',
#  '[Mo+4]',
#  '[Si+]',
#  '[BH]',
#  '[Be]',
#  '[Rb]',
#  '[pH]',
#  '%19',
#  '%20',
#  '[Xe]',
#  '[Ir-]',
#  '[Be+2]',
#  '[C+4]',
#  '[RuH2]',
#  '[15NH]',
#  '[U+2]',
#  '[Au-]',
#  '%21',
#  '%22',
#  '[Au+]',
#  '[15n]',
#  '[Al+2]',
#  '[Tb+3]',
#  '[15N]',
#  '[V+3]',
#  '[W+6]',
#  '[14CH3]',
#  '[Cr+4]',
#  '[ClH+]',
#  'b',
#  '[Ti+6]',
#  '[Nd+]',
#  '[Zr+]',
#  '[PH2+]',
#  '[Fm]',
#  '[N@H+]',
#  '[RuH]',
#  '[Dy+3]',
#  '%23',
#  '[Hf+3]',
#  '[W+4]',
#  '[11C]',
#  '[13CH]',
#  '[Er]',
#  '[124I]',
#  '[LaH]',
#  '[F]',
#  '[siH]',
#  '[Ga+]',
#  '[Cm]',
#  '[GeH3]',
#  '[IH-]',
#  '[U+6]',
#  '[SeH+]',
#  '[32P]',
#  '[SeH-]',
#  '[Pt-]',
#  '[Ir+2]',
#  '[se+]',
#  '[U]',
#  '[F+]',
#  '[BH2]',
#  '[As+]',
#  '[Cf]',
#  '[ClH2+]',
#  '[Ni+]',
#  '[TeH3]',
#  '[SbH2]',
#  '[Ag+3]',
#  '%24',
#  '[18O]',
#  '[PH4]',
#  '[Os+2]',
#  '[Na-]',
#  '[Sb+2]',
#  '[V+4]',
#  '[Ho+3]',
#  '[68Ga]',
#  '[PH-]',
#  '[Bi+2]',
#  '[Ce+2]',
#  '[Pd+3]',
#  '[99Tc]',
#  '[13C@@H]',
#  '[Fe+6]',
#  '[c]',
#  '[GeH2]',
#  '[10B]',
#  '[Cu+3]',
#  '[Mo+2]',
#  '[Cr+]',
#  '[Pd+4]',
#  '[Dy]',
#  '[AsH]',
#  '[Ba+]',
#  '[SeH2]',
#  '[In+]',
#  '[TeH2]',
#  '[BrH+]',
#  '[14cH]',
#  '[W+]',
#  '[13C@H]',
#  '[AsH2]',
#  '[In+2]',
#  '[N+2]',
#  '[N@@H+]',
#  '[SbH]',
#  '[60Co]',
#  '[AsH4+]',
#  '[AsH3]',
#  '[18OH]',
#  '[Ru-2]',
#  '[Na-2]',
#  '[CuH2]',
#  '[31P]',
#  '[Ti+5]',
#  '[35S]',
#  '[P@@H]',
#  '[ArH]',
#  '[Co+]',
#  '[Zr-2]',
#  '[BH2-]',
#  '[131I]',
#  '[SH5]',
#  '[VH]',
#  '[B+2]',
#  '[Yb+2]',
#  '[14C@H]',
#  '[211At]',
#  '[NH3+2]',
#  '[IrH]',
#  '[IrH2]',
#  '[Rh-]',
#  '[Cr-]',
#  '[Sb+]',
#  '[Ni+3]',
#  '[TaH3]',
#  '[Tl+2]',
#  '[64Cu]',
#  '[Tc]',
#  '[Cd+]',
#  '[1H]',
#  '[15nH]',
#  '[AlH2+]',
#  '[FH+2]',
#  '[BiH3]',
#  '[Ru-]',
#  '[Mo+6]',
#  '[AsH+]',
#  '[BaH2]',
#  '[BaH]',
#  '[Fe+4]',
#  '[229Th]',
#  '[Th+4]',
#  '[As+3]',
#  '[NH+3]',
#  '[P@H]',
#  '[Li-]',
#  '[7NaH]',
#  '[Bi+]',
#  '[PtH+2]',
#  '[p-]',
#  '[Re+5]',
#  '[NiH]',
#  '[Ni-]',
#  '[Xe+]',
#  '[Ca+]',
#  '[11c]',
#  '[Rh+4]',
#  '[AcH]',
#  '[HeH]',
#  '[Sc+2]',
#  '[Mn+]',
#  '[UH]',
#  '[14CH2]',
#  '[SiH4+]',
#  '[18OH2]',
#  '[Ac-]',
#  '[Re+4]',
#  '[118Sn]',
#  '[153Sm]',
#  '[P+2]',
#  '[9CH]',
#  '[9CH3]',
#  '[Y-]',
#  '[NiH2]',
#  '[Si+2]',
#  '[Mn+6]',
#  '[ZrH2]',
#  '[C-2]',
#  '[Bi+5]',
#  '[24NaH]',
#  '[Fr]',
#  '[15CH]',
#  '[Se+]',
#  '[At]',
#  '[P-3]',
#  '[124I-]',
#  '[CuH2-]',
#  '[Nb+4]',
#  '[Nb+3]',
#  '[MgH]',
#  '[Ir+4]',
#  '[67Ga+3]',
#  '[67Ga]',
#  '[13N]',
#  '[15OH2]',
#  '[2NH]',
#  '[Ho]',
#  '[Cn]']

# %%
# prepend our special tokens
final_vocab_tokens = special_tokens + filtered_vocab_tokens

print("Len", len(final_vocab_tokens))
final_vocab_tokens
# Out:
# Len 593
# ['<s>',
#  '[PAD]',
#  '</s>',
#  '[UNK]',
#  '[SEP]',
#  '[CLS]',
#  '[MASK]',
#  '[unused1]',
#  '[unused2]',
#  '[unused3]',
#  '[unused4]',
#  '[unused5]',
#  '[unused6]',
#  '[unused7]',
#  '[unused8]',
#  '[unused9]',
#  '[unused10]',
#  'c',
#  'C',
#  '(',
#  ')',
#  'O',
#  '1',
#  '2',
#  '=',
#  'N',
#  '.',
#  'n',
#  '3',
#  'F',
#  'Cl',
#  '>>',
#  '~',
#  '-',
#  '4',
#  '[C@H]',
#  'S',
#  '[C@@H]',
#  '[O-]',
#  'Br',
#  '#',
#  '/',
#  '[nH]',
#  '[N+]',
#  's',
#  '5',
#  'o',
#  'P',
#  '[Na+]',
#  '[Si]',
#  'I',
#  '[Na]',
#  '[Pd]',
#  '[K+]',
#  '[K]',
#  '[P]',
#  'B',
#  '[C@]',
#  '[C@@]',
#  '[Cl-]',
#  '6',
#  '[OH-]',
#  '\\',
#  '[N-]',
#  '[Li]',
#  '[H]',
#  '[2H]',
#  '[NH4+]',
#  '[c-]',
#  '[P-]',
#  '[Cs+]',
#  '[Li+]',
#  '[Cs]',
#  '[NaH]',
#  '[H-]',
#  '[O+]',
#  '[BH4-]',
#  '[Cu]',
#  '7',
#  '[Mg]',
#  '[Fe+2]',
#  '[n+]',
#  '[Sn]',
#  '[BH-]',
#  '[Pd+2]',
#  '[CH]',
#  '[I-]',
#  '[Br-]',
#  '[C-]',
#  '[Zn]',
#  '[B-]',
#  '[F-]',
#  '[Al]',
#  '[P+]',
#  '[BH3-]',
#  '[Fe]',
#  '[C]',
#  '[AlH4]',
#  '[Ni]',
#  '[SiH]',
#  '8',
#  '[Cu+2]',
#  '[Mn]',
#  '[AlH]',
#  '[nH+]',
#  '[AlH4-]',
#  '[O-2]',
#  '[Cr]',
#  '[Mg+2]',
#  '[NH3+]',
#  '[S@]',
#  '[Pt]',
#  '[Al+3]',
#  '[S@@]',
#  '[S-]',
#  '[Ti]',
#  '[Zn+2]',
#  '[PH]',
#  '[NH2+]',
#  '[Ru]',
#  '[Ag+]',
#  '[S+]',
#  '[I+3]',
#  '[NH+]',
#  '[Ca+2]',
#  '[Ag]',
#  '9',
#  '[Os]',
#  '[Se]',
#  '[SiH2]',
#  '[Ca]',
#  '[Ti+4]',
#  '[Ac]',
#  '[Cu+]',
#  '[S]',
#  '[Rh]',
#  '[Cl+3]',
#  '[cH-]',
#  '[Zn+]',
#  '[O]',
#  '[Cl+]',
#  '[SH]',
#  '[H+]',
#  '[Pd+]',
#  '[se]',
#  '[PH+]',
#  '[I]',
#  '[Pt+2]',
#  '[C+]',
#  '[Mg+]',
#  '[Hg]',
#  '[W]',
#  '[SnH]',
#  '[SiH3]',
#  '[Fe+3]',
#  '[NH]',
#  '[Mo]',
#  '[CH2+]',
#  '%10',
#  '[CH2-]',
#  '[CH2]',
#  '[n-]',
#  '[Ce+4]',
#  '[NH-]',
#  '[Co]',
#  '[I+]',
#  '[PH2]',
#  '[Pt+4]',
#  '[Ce]',
#  '[B]',
#  '[Sn+2]',
#  '[Ba+2]',
#  '%11',
#  '[Fe-3]',
#  '[18F]',
#  '[SH-]',
#  '[Pb+2]',
#  '[Os-2]',
#  '[Zr+4]',
#  '[N]',
#  '[Ir]',
#  '[Bi]',
#  '[Ni+2]',
#  '[P@]',
#  '[Co+2]',
#  '[s+]',
#  '[As]',
#  '[P+3]',
#  '[Hg+2]',
#  '[Yb+3]',
#  '[CH-]',
#  '[Zr+2]',
#  '[Mn+2]',
#  '[CH+]',
#  '[In]',
#  '[KH]',
#  '[Ce+3]',
#  '[Zr]',
#  '[AlH2-]',
#  '[OH2+]',
#  '[Ti+3]',
#  '[Rh+2]',
#  '[Sb]',
#  '[S-2]',
#  '%12',
#  '[P@@]',
#  '[Si@H]',
#  '[Mn+4]',
#  'p',
#  '[Ba]',
#  '[NH2-]',
#  '[Ge]',
#  '[Pb+4]',
#  '[Cr+3]',
#  '[Au]',
#  '[LiH]',
#  '[Sc+3]',
#  '[o+]',
#  '[Rh-3]',
#  '%13',
#  '[Br]',
#  '[Sb-]',
#  '[S@+]',
#  '[I+2]',
#  '[Ar]',
#  '[V]',
#  '[Cu-]',
#  '[Al-]',
#  '[Te]',
#  '[13c]',
#  '[13C]',
#  '[Cl]',
#  '[PH4+]',
#  '[SiH4]',
#  '[te]',
#  '[CH3-]',
#  '[S@@+]',
#  '[Rh+3]',
#  '[SH+]',
#  '[Bi+3]',
#  '[Br+2]',
#  '[La]',
#  '[La+3]',
#  '[Pt-2]',
#  '[N@@]',
#  '[PH3+]',
#  '[N@]',
#  '[Si+4]',
#  '[Sr+2]',
#  '[Al+]',
#  '[Pb]',
#  '[SeH]',
#  '[Si-]',
#  '[V+5]',
#  '[Y+3]',
#  '[Re]',
#  '[Ru+]',
#  '[Sm]',
#  '*',
#  '[3H]',
#  '[NH2]',
#  '[Ag-]',
#  '[13CH3]',
#  '[OH+]',
#  '[Ru+3]',
#  '[OH]',
#  '[Gd+3]',
#  '[13CH2]',
#  '[In+3]',
#  '[Si@@]',
#  '[Si@]',
#  '[Ti+2]',
#  '[Sn+]',
#  '[Cl+2]',
#  '[AlH-]',
#  '[Pd-2]',
#  '[SnH3]',
#  '[B+3]',
#  '[Cu-2]',
#  '[Nd+3]',
#  '[Pb+3]',
#  '[13cH]',
#  '[Fe-4]',
#  '[Ga]',
#  '[Sn+4]',
#  '[Hg+]',
#  '[11CH3]',
#  '[Hf]',
#  '[Pr]',
#  '[Y]',
#  '[S+2]',
#  '[Cd]',
#  '[Cr+6]',
#  '[Zr+3]',
#  '[Rh+]',
#  '[CH3]',
#  '[N-3]',
#  '[Hf+2]',
#  '[Th]',
#  '[Sb+3]',
#  '%14',
#  '[Cr+2]',
#  '[Ru+2]',
#  '[Hf+4]',
#  '[14C]',
#  '[Ta]',
#  '[Tl+]',
#  '[B+]',
#  '[Os+4]',
#  '[PdH2]',
#  '[Pd-]',
#  '[Cd+2]',
#  '[Co+3]',
#  '[S+4]',
#  '[Nb+5]',
#  '[123I]',
#  '[c+]',
#  '[Rb+]',
#  '[V+2]',
#  '[CH3+]',
#  '[Ag+2]',
#  '[cH+]',
#  '[Mn+3]',
#  '[Se-]',
#  '[As-]',
#  '[Eu+3]',
#  '[SH2]',
#  '[Sm+3]',
#  '[IH+]',
#  '%15',
#  '[OH3+]',
#  '[PH3]',
#  '[IH2+]',
#  '[SH2+]',
#  '[Ir+3]',
#  '[AlH3]',
#  '[Sc]',
#  '[Yb]',
#  '[15NH2]',
#  '[Lu]',
#  '[sH+]',
#  '[Gd]',
#  '[18F-]',
#  '[SH3+]',
#  '[SnH4]',
#  '[TeH]',
#  '[Si@@H]',
#  '[Ga+3]',
#  '[CaH2]',
#  '[Tl]',
#  '[Ta+5]',
#  '[GeH]',
#  '[Br+]',
#  '[Sr]',
#  '[Tl+3]',
#  '[Sm+2]',
#  '[PH5]',
#  '%16',
#  '[N@@+]',
#  '[Au+3]',
#  '[C-4]',
#  '[Nd]',
#  '[Ti+]',
#  '[IH]',
#  '[N@+]',
#  '[125I]',
#  '[Eu]',
#  '[Sn+3]',
#  '[Nb]',
#  '[Er+3]',
#  '[123I-]',
#  '[14c]',
#  '%17',
#  '[SnH2]',
#  '[YH]',
#  '[Sb+5]',
#  '[Pr+3]',
#  '[Ir+]',
#  '[N+3]',
#  '[AlH2]',
#  '[19F]',
#  '%18',
#  '[Tb]',
#  '[14CH]',
#  '[Mo+4]',
#  '[Si+]',
#  '[BH]',
#  '[Be]',
#  '[Rb]',
#  '[pH]',
#  '%19',
#  '%20',
#  '[Xe]',
#  '[Ir-]',
#  '[Be+2]',
#  '[C+4]',
#  '[RuH2]',
#  '[15NH]',
#  '[U+2]',
#  '[Au-]',
#  '%21',
#  '%22',
#  '[Au+]',
#  '[15n]',
#  '[Al+2]',
#  '[Tb+3]',
#  '[15N]',
#  '[V+3]',
#  '[W+6]',
#  '[14CH3]',
#  '[Cr+4]',
#  '[ClH+]',
#  'b',
#  '[Ti+6]',
#  '[Nd+]',
#  '[Zr+]',
#  '[PH2+]',
#  '[Fm]',
#  '[N@H+]',
#  '[RuH]',
#  '[Dy+3]',
#  '%23',
#  '[Hf+3]',
#  '[W+4]',
#  '[11C]',
#  '[13CH]',
#  '[Er]',
#  '[124I]',
#  '[LaH]',
#  '[F]',
#  '[siH]',
#  '[Ga+]',
#  '[Cm]',
#  '[GeH3]',
#  '[IH-]',
#  '[U+6]',
#  '[SeH+]',
#  '[32P]',
#  '[SeH-]',
#  '[Pt-]',
#  '[Ir+2]',
#  '[se+]',
#  '[U]',
#  '[F+]',
#  '[BH2]',
#  '[As+]',
#  '[Cf]',
#  '[ClH2+]',
#  '[Ni+]',
#  '[TeH3]',
#  '[SbH2]',
#  '[Ag+3]',
#  '%24',
#  '[18O]',
#  '[PH4]',
#  '[Os+2]',
#  '[Na-]',
#  '[Sb+2]',
#  '[V+4]',
#  '[Ho+3]',
#  '[68Ga]',
#  '[PH-]',
#  '[Bi+2]',
#  '[Ce+2]',
#  '[Pd+3]',
#  '[99Tc]',
#  '[13C@@H]',
#  '[Fe+6]',
#  '[c]',
#  '[GeH2]',
#  '[10B]',
#  '[Cu+3]',
#  '[Mo+2]',
#  '[Cr+]',
#  '[Pd+4]',
#  '[Dy]',
#  '[AsH]',
#  '[Ba+]',
#  '[SeH2]',
#  '[In+]',
#  '[TeH2]',
#  '[BrH+]',
#  '[14cH]',
#  '[W+]',
#  '[13C@H]',
#  '[AsH2]',
#  '[In+2]',
#  '[N+2]',
#  '[N@@H+]',
#  '[SbH]',
#  '[60Co]',
#  '[AsH4+]',
#  '[AsH3]',
#  '[18OH]',
#  '[Ru-2]',
#  '[Na-2]',
#  '[CuH2]',
#  '[31P]',
#  '[Ti+5]',
#  '[35S]',
#  '[P@@H]',
#  '[ArH]',
#  '[Co+]',
#  '[Zr-2]',
#  '[BH2-]',
#  '[131I]',
#  '[SH5]',
#  '[VH]',
#  '[B+2]',
#  '[Yb+2]',
#  '[14C@H]',
#  '[211At]',
#  '[NH3+2]',
#  '[IrH]',
#  '[IrH2]',
#  '[Rh-]',
#  '[Cr-]',
#  '[Sb+]',
#  '[Ni+3]',
#  '[TaH3]',
#  '[Tl+2]',
#  '[64Cu]',
#  '[Tc]',
#  '[Cd+]',
#  '[1H]',
#  '[15nH]',
#  '[AlH2+]',
#  '[FH+2]',
#  '[BiH3]',
#  '[Ru-]',
#  '[Mo+6]',
#  '[AsH+]',
#  '[BaH2]',
#  '[BaH]',
#  '[Fe+4]',
#  '[229Th]',
#  '[Th+4]',
#  '[As+3]',
#  '[NH+3]',
#  '[P@H]',
#  '[Li-]',
#  '[7NaH]',
#  '[Bi+]',
#  '[PtH+2]',
#  '[p-]',
#  '[Re+5]',
#  '[NiH]',
#  '[Ni-]',
#  '[Xe+]',
#  '[Ca+]',
#  '[11c]',
#  '[Rh+4]',
#  '[AcH]',
#  '[HeH]',
#  '[Sc+2]',
#  '[Mn+]',
#  '[UH]',
#  '[14CH2]',
#  '[SiH4+]',
#  '[18OH2]',
#  '[Ac-]',
#  '[Re+4]',
#  '[118Sn]',
#  '[153Sm]',
#  '[P+2]',
#  '[9CH]',
#  '[9CH3]',
#  '[Y-]',
#  '[NiH2]',
#  '[Si+2]',
#  '[Mn+6]',
#  '[ZrH2]',
#  '[C-2]',
#  '[Bi+5]',
#  '[24NaH]',
#  '[Fr]',
#  '[15CH]',
#  '[Se+]',
#  '[At]',
#  '[P-3]',
#  '[124I-]',
#  '[CuH2-]',
#  '[Nb+4]',
#  '[Nb+3]',
#  '[MgH]',
#  '[Ir+4]',
#  '[67Ga+3]',
#  '[67Ga]',
#  '[13N]',
#  '[15OH2]',
#  '[2NH]',
#  '[Ho]',
#  '[Cn]']

# %%
# Write
with open("./vocab.txt", "w") as f:
    for token in final_vocab_tokens:
        f.write(token+"\n")
    print('Done')
# Out:
# Done

# %%
# Read
with open("./vocab.txt", "r") as f:
    k = f.read().splitlines()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Read
# ----> 2 with open("./vocab.txt", "r") as f:
#       3     k = f.read().splitlines()
#
# File ~/miniconda3/envs/molgen/lib/python3.11/site-packages/IPython/core/interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: './vocab.txt'

# %%
vocab = OrderedDict()

for index, token in enumerate(k):
    token = token.rstrip("\n")
    vocab[token] = index

# %%
assert len(final_vocab_tokens) == len(vocab)

# %%
test_smiles = "CCc1c[nH]c2[O-]c1CC(N)C2(Cl)C[N+]"

# %% [markdown]
# ### Old tokenizer

# %%
from tokenizers import Tokenizer

# %%
# it was created by modified tokenizer.json from https://huggingface.co/DeepChem/SmilesTokenizer_PubChem_1M/tree/main 
# BPE Tokenizer
tokenizer_old = Tokenizer.from_file("./tokenizers/tokenizer_sm/old_tokenizer_smiles.json")

# %%
tokenizer_old.encode(test_smiles).tokens
# Out:
# ['[CLS]',
#  'C',
#  'C',
#  'c',
#  '1',
#  'c',
#  'n',
#  'c',
#  '2',
#  'O',
#  '-',
#  'c',
#  '1',
#  'C',
#  'C',
#  '(',
#  'N',
#  ')',
#  'C',
#  '2',
#  '(',
#  'C',
#  ')',
#  'C',
#  'N',
#  '[SEP]']

# %% [markdown]
# ### DeepChem tokenizer

# %%
# from https://github.com/deepchem/deepchem/blob/master/deepchem/feat/smiles_tokenizer.py
from deepchem_smiles_tokenizer import SmilesTokenizer, BasicSmilesTokenizer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 2
#       1 # from https://github.com/deepchem/deepchem/blob/master/deepchem/feat/smiles_tokenizer.py
# ----> 2 from deepchem_smiles_tokenizer import SmilesTokenizer, BasicSmilesTokenizer
#
# ModuleNotFoundError: No module named 'deepchem_smiles_tokenizer'

# %%
tokenizer_deepchem = SmilesTokenizer("./deepchem_vocab.json")

# %%
tokenizer_deepchem.tokenize(test_smiles)
# Out:
# ['C',
#  'C',
#  'c',
#  '1',
#  'c',
#  '[nH]',
#  'c',
#  '2',
#  '[O-]',
#  'c',
#  '1',
#  'C',
#  'C',
#  '(',
#  'N',
#  ')',
#  'C',
#  '2',
#  '(',
#  'Cl',
#  ')',
#  'C',
#  '[N+]']

# %% [markdown]
# ### SMILES Pair Encoding tokenizer

# %%
# https://github.com/XinhaoLi74/SmilesPE
from SmilesPE.pretokenizer import atomwise_tokenizer

atomwise_tokenizer(test_smiles)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 2
#       1 # https://github.com/XinhaoLi74/SmilesPE
# ----> 2 from SmilesPE.pretokenizer import atomwise_tokenizer
#       4 atomwise_tokenizer(test_smiles)
#
# ModuleNotFoundError: No module named 'SmilesPE'

# %% [markdown]
# ### Bert WordPiece tokenizer

# %%
from tokenizers import BertWordPieceTokenizer, Tokenizer, pre_tokenizers
import re

SMI_REGEX_PATTERN = r"""(\[[^\]]+]|Br?|Cl?|N|O|S|P|F|I|b|c|n|o|s|p|\(|\)|\.|=|#|-|\+|\\|\/|:|~|@|\?|>>?|\*|\$|\%[0-9]{2}|[0-9])"""

tokenizer_wordpiece = BertWordPieceTokenizer.from_file(
                "./tokenizers/tokenizer_sm/vocab.txt", 
                clean_text=False,
                handle_chinese_chars=False,
                strip_accents=False,
                lowercase=False
            )

# %%
regex = re.compile(SMI_REGEX_PATTERN)

# code from metaseq
test_smiles_tokens = [token for token in regex.findall(test_smiles.rstrip())]
test_smiles_tokens
# Out:
# ['C',
#  'C',
#  'c',
#  '1',
#  'c',
#  '[nH]',
#  'c',
#  '2',
#  '[O-]',
#  'c',
#  '1',
#  'C',
#  'C',
#  '(',
#  'N',
#  ')',
#  'C',
#  '2',
#  '(',
#  'Cl',
#  ')',
#  'C',
#  '[N+]']

# %%
tokenizer_wordpiece.encode(test_smiles_tokens, is_pretokenized=True).tokens
# Out:
# ['[CLS]',
#  'C',
#  'C',
#  'c',
#  '1',
#  'c',
#  '[UNK]',
#  '[UNK]',
#  '[UNK]',
#  'c',
#  '2',
#  '[UNK]',
#  'O',
#  '-',
#  '[UNK]',
#  'c',
#  '1',
#  'C',
#  'C',
#  '(',
#  'N',
#  ')',
#  'C',
#  '2',
#  '(',
#  'Cl',
#  ')',
#  'C',
#  '[UNK]',
#  'N',
#  '[UNK]',
#  '[UNK]',
#  '[SEP]']

# %%
# Reason
# Although the is_pretokenized=False, it does also Punctuation pretokenization
tokenizer_wordpiece.encode(["[nH]"], is_pretokenized=True).tokens
# Out:
# ['[CLS]', '[UNK]', '[UNK]', '[UNK]', '[SEP]']

# %%
# TRICK to get ride of Punctuation pretokenizer
tokenizer_wordpiece.pre_tokenizer = pre_tokenizers.CharDelimiterSplit(delimiter="&")

# %%
# Now the Punctuation pretokenizer is off, that's why tokenizer treats '[nH]' as one token
tokenizer_wordpiece.encode(["[nH]"], is_pretokenized=True).tokens
# Out:
# ['[CLS]', '[nH]', '[SEP]']

# %%
tokenizer_wordpiece.encode(test_smiles_tokens, is_pretokenized=True).tokens
# Out:
# ['[CLS]',
#  'C',
#  'C',
#  'c',
#  '1',
#  'c',
#  '[nH]',
#  'c',
#  '2',
#  '[O-]',
#  'c',
#  '1',
#  'C',
#  'C',
#  '(',
#  'N',
#  ')',
#  'C',
#  '2',
#  '(',
#  'Cl',
#  ')',
#  'C',
#  '[N+]',
#  '[SEP]']

# %%
# Official implementation of WordPiece https://huggingface.co/learn/nlp-course/chapter6/6?fw=pt 
def encode_word(word):
    tokens = []
    while len(word) > 0:
        i = len(word)
        while i > 0 and word[:i] not in tokenizer_wordpiece.get_vocab():
            i -= 1
        if i == 0:
            return ["[UNK]"]
        tokens.append(word[:i])
        word = word[i:]
        if len(word) > 0:
            word = f"##{word}"
    return tokens

# %%
tokenizer_wordpiece.normalizer.normalize_str("C[nH]")
# Out:
# 'C[nH]'

# %%
encode_word("[nH]")
# Out:
# ['[nH]']

# %% [markdown]
# ### Default Transformers Tokenizers

# %%
from transformers import BertTokenizer, T5Tokenizer, GPT2Tokenizer

# %%
# WordPiece
bert_tokenizer = BertTokenizer.from_pretrained("bert-base-cased")

# %%
# BPE
gpt_tokenizer = GPT2Tokenizer.from_pretrained("gpt2")

# %%
# SentencePiece
t5_tokenizer = T5Tokenizer.from_pretrained("t5-large", model_max_length=512)

# %%
# Vocab sizes
len(bert_tokenizer.get_vocab()), len(gpt_tokenizer.get_vocab()), len(t5_tokenizer.get_vocab())
# Out:
# (28996, 50257, 32100)

# %%
text_1 = "I have a new GPU!"

# %%
text_2 = "Don't you love 🤗 Transformers? We sure do."

# %%
text_3 = "CCc1c[nH]c2[O-]c1CC(N)C2(Cl)C[N+]"

# %%
# Text 1

# %%
bert_tokenizer.tokenize(text_1)
# Out:
# ['I', 'have', 'a', 'new', 'GP', '##U', '!']

# %%
gpt_tokenizer.tokenize(text_1)
# Out:
# ['I', 'Ġhave', 'Ġa', 'Ġnew', 'ĠGPU', '!']

# %%
t5_tokenizer.tokenize(text_1)
# Out:
# ['▁I', '▁have', '▁', 'a', '▁new', '▁GPU', '!']

# %%
# Text 2

# %%
bert_tokenizer.tokenize(text_2)
# Out:
# ['Don',
#  "'",
#  't',
#  'you',
#  'love',
#  '[UNK]',
#  'Transformers',
#  '?',
#  'We',
#  'sure',
#  'do',
#  '.']

# %%
gpt_tokenizer.tokenize(text_2)
# Out:
# ['Don',
#  "'t",
#  'Ġyou',
#  'Ġlove',
#  'ĠðŁ',
#  '¤',
#  'Ĺ',
#  'ĠTransformers',
#  '?',
#  'ĠWe',
#  'Ġsure',
#  'Ġdo',
#  '.']

# %%
t5_tokenizer.tokenize(text_2)
# Out:
# ['▁Don',
#  "'",
#  't',
#  '▁you',
#  '▁love',
#  '▁',
#  '🤗',
#  '▁Transformer',
#  's',
#  '?',
#  '▁We',
#  '▁sure',
#  '▁do',
#  '.']

# %%
# Text 3

# %%
bert_tokenizer.tokenize(text_3)
# Out:
# ['CC',
#  '##c',
#  '##1',
#  '##c',
#  '[',
#  'n',
#  '##H',
#  ']',
#  'c',
#  '##2',
#  '[',
#  'O',
#  '-',
#  ']',
#  'c',
#  '##1',
#  '##CC',
#  '(',
#  'N',
#  ')',
#  'C',
#  '##2',
#  '(',
#  'C',
#  '##l',
#  ')',
#  'C',
#  '[',
#  'N',
#  '+',
#  ']']

# %%
gpt_tokenizer.tokenize(text_3)
# Out:
# ['CC',
#  'c',
#  '1',
#  'c',
#  '[',
#  'n',
#  'H',
#  ']',
#  'c',
#  '2',
#  '[',
#  'O',
#  '-',
#  ']',
#  'c',
#  '1',
#  'CC',
#  '(',
#  'N',
#  ')',
#  'C',
#  '2',
#  '(',
#  'Cl',
#  ')',
#  'C',
#  '[',
#  'N',
#  '+',
#  ']']

# %%
t5_tokenizer.tokenize(text_3)
# Out:
# ['▁',
#  'CC',
#  'c',
#  '1',
#  'c',
#  '[',
#  'n',
#  'H',
#  ']',
#  'c',
#  '2',
#  '[',
#  'O',
#  '-',
#  ']',
#  'c',
#  '1',
#  'CC',
#  '(',
#  'N',
#  ')',
#  'C',
#  '2',
#  '(',
#  'C',
#  'l',
#  ')',
#  'C',
#  '[',
#  'N',
#  '+',
#  ']']

# %%
test_smiles = "CCc1c[nH]c2[O-]c1CC(N)C2(Cl)C[N+]"

# %%
from tokenizers import Tokenizer

from transformers import PreTrainedTokenizerFast

# %%
sf_like_tokenizer_path = "/auto/home/knarik/Molecular_Generation_with_GDB13/src/data/tokenizers/tokenizer_sm/tokenizer.json"

# %%
sm_like_tokenizer = Tokenizer.from_file(sf_like_tokenizer_path)

# %%
tokenizer = PreTrainedTokenizerFast(tokenizer_object=sm_like_tokenizer)

# %%
tokenizer.tokenize(test_smiles)
# Out:
# ['C',
#  'C',
#  'c',
#  '1',
#  'c',
#  '[nH]',
#  'c',
#  '2',
#  '[O-]',
#  'c',
#  '1',
#  'C',
#  'C',
#  '(',
#  'N',
#  ')',
#  'C',
#  '2',
#  '(',
#  'Cl',
#  ')',
#  'C',
#  '[N+]']

# %%
tokenizer("[C][N]")
# Out:
# {'input_ids': [0, 86, 169, 2], 'token_type_ids': [0, 0, 0, 0], 'attention_mask': [1, 1, 1, 1]}

# %%
tokenizer.tokenize("[C][N]")
# Out:
# ['[C]', '[N]']

# %%
len(tokenizer.get_vocab())
# Out:
# 583

# %%
import json

# %%
with open("./tokenizers/tokenizer_sm/vocab.txt", "r") as f:
    sm_old_vocab = f.read().splitlines()

# %%
len(sm_old_vocab)
# Out:
# 593

# %%
sm_old_vocab
# Out:
# ['<s>',
#  '[PAD]',
#  '</s>',
#  '[UNK]',
#  '[SEP]',
#  '[CLS]',
#  '[MASK]',
#  '[unused1]',
#  '[unused2]',
#  '[unused3]',
#  '[unused4]',
#  '[unused5]',
#  '[unused6]',
#  '[unused7]',
#  '[unused8]',
#  '[unused9]',
#  '[unused10]',
#  'c',
#  'C',
#  '(',
#  ')',
#  'O',
#  '1',
#  '2',
#  '=',
#  'N',
#  '.',
#  'n',
#  '3',
#  'F',
#  'Cl',
#  '>>',
#  '~',
#  '-',
#  '4',
#  '[C@H]',
#  'S',
#  '[C@@H]',
#  '[O-]',
#  'Br',
#  '#',
#  '/',
#  '[nH]',
#  '[N+]',
#  's',
#  '5',
#  'o',
#  'P',
#  '[Na+]',
#  '[Si]',
#  'I',
#  '[Na]',
#  '[Pd]',
#  '[K+]',
#  '[K]',
#  '[P]',
#  'B',
#  '[C@]',
#  '[C@@]',
#  '[Cl-]',
#  '6',
#  '[OH-]',
#  '\\',
#  '[N-]',
#  '[Li]',
#  '[H]',
#  '[2H]',
#  '[NH4+]',
#  '[c-]',
#  '[P-]',
#  '[Cs+]',
#  '[Li+]',
#  '[Cs]',
#  '[NaH]',
#  '[H-]',
#  '[O+]',
#  '[BH4-]',
#  '[Cu]',
#  '7',
#  '[Mg]',
#  '[Fe+2]',
#  '[n+]',
#  '[Sn]',
#  '[BH-]',
#  '[Pd+2]',
#  '[CH]',
#  '[I-]',
#  '[Br-]',
#  '[C-]',
#  '[Zn]',
#  '[B-]',
#  '[F-]',
#  '[Al]',
#  '[P+]',
#  '[BH3-]',
#  '[Fe]',
#  '[C]',
#  '[AlH4]',
#  '[Ni]',
#  '[SiH]',
#  '8',
#  '[Cu+2]',
#  '[Mn]',
#  '[AlH]',
#  '[nH+]',
#  '[AlH4-]',
#  '[O-2]',
#  '[Cr]',
#  '[Mg+2]',
#  '[NH3+]',
#  '[S@]',
#  '[Pt]',
#  '[Al+3]',
#  '[S@@]',
#  '[S-]',
#  '[Ti]',
#  '[Zn+2]',
#  '[PH]',
#  '[NH2+]',
#  '[Ru]',
#  '[Ag+]',
#  '[S+]',
#  '[I+3]',
#  '[NH+]',
#  '[Ca+2]',
#  '[Ag]',
#  '9',
#  '[Os]',
#  '[Se]',
#  '[SiH2]',
#  '[Ca]',
#  '[Ti+4]',
#  '[Ac]',
#  '[Cu+]',
#  '[S]',
#  '[Rh]',
#  '[Cl+3]',
#  '[cH-]',
#  '[Zn+]',
#  '[O]',
#  '[Cl+]',
#  '[SH]',
#  '[H+]',
#  '[Pd+]',
#  '[se]',
#  '[PH+]',
#  '[I]',
#  '[Pt+2]',
#  '[C+]',
#  '[Mg+]',
#  '[Hg]',
#  '[W]',
#  '[SnH]',
#  '[SiH3]',
#  '[Fe+3]',
#  '[NH]',
#  '[Mo]',
#  '[CH2+]',
#  '%10',
#  '[CH2-]',
#  '[CH2]',
#  '[n-]',
#  '[Ce+4]',
#  '[NH-]',
#  '[Co]',
#  '[I+]',
#  '[PH2]',
#  '[Pt+4]',
#  '[Ce]',
#  '[B]',
#  '[Sn+2]',
#  '[Ba+2]',
#  '%11',
#  '[Fe-3]',
#  '[18F]',
#  '[SH-]',
#  '[Pb+2]',
#  '[Os-2]',
#  '[Zr+4]',
#  '[N]',
#  '[Ir]',
#  '[Bi]',
#  '[Ni+2]',
#  '[P@]',
#  '[Co+2]',
#  '[s+]',
#  '[As]',
#  '[P+3]',
#  '[Hg+2]',
#  '[Yb+3]',
#  '[CH-]',
#  '[Zr+2]',
#  '[Mn+2]',
#  '[CH+]',
#  '[In]',
#  '[KH]',
#  '[Ce+3]',
#  '[Zr]',
#  '[AlH2-]',
#  '[OH2+]',
#  '[Ti+3]',
#  '[Rh+2]',
#  '[Sb]',
#  '[S-2]',
#  '%12',
#  '[P@@]',
#  '[Si@H]',
#  '[Mn+4]',
#  'p',
#  '[Ba]',
#  '[NH2-]',
#  '[Ge]',
#  '[Pb+4]',
#  '[Cr+3]',
#  '[Au]',
#  '[LiH]',
#  '[Sc+3]',
#  '[o+]',
#  '[Rh-3]',
#  '%13',
#  '[Br]',
#  '[Sb-]',
#  '[S@+]',
#  '[I+2]',
#  '[Ar]',
#  '[V]',
#  '[Cu-]',
#  '[Al-]',
#  '[Te]',
#  '[13c]',
#  '[13C]',
#  '[Cl]',
#  '[PH4+]',
#  '[SiH4]',
#  '[te]',
#  '[CH3-]',
#  '[S@@+]',
#  '[Rh+3]',
#  '[SH+]',
#  '[Bi+3]',
#  '[Br+2]',
#  '[La]',
#  '[La+3]',
#  '[Pt-2]',
#  '[N@@]',
#  '[PH3+]',
#  '[N@]',
#  '[Si+4]',
#  '[Sr+2]',
#  '[Al+]',
#  '[Pb]',
#  '[SeH]',
#  '[Si-]',
#  '[V+5]',
#  '[Y+3]',
#  '[Re]',
#  '[Ru+]',
#  '[Sm]',
#  '*',
#  '[3H]',
#  '[NH2]',
#  '[Ag-]',
#  '[13CH3]',
#  '[OH+]',
#  '[Ru+3]',
#  '[OH]',
#  '[Gd+3]',
#  '[13CH2]',
#  '[In+3]',
#  '[Si@@]',
#  '[Si@]',
#  '[Ti+2]',
#  '[Sn+]',
#  '[Cl+2]',
#  '[AlH-]',
#  '[Pd-2]',
#  '[SnH3]',
#  '[B+3]',
#  '[Cu-2]',
#  '[Nd+3]',
#  '[Pb+3]',
#  '[13cH]',
#  '[Fe-4]',
#  '[Ga]',
#  '[Sn+4]',
#  '[Hg+]',
#  '[11CH3]',
#  '[Hf]',
#  '[Pr]',
#  '[Y]',
#  '[S+2]',
#  '[Cd]',
#  '[Cr+6]',
#  '[Zr+3]',
#  '[Rh+]',
#  '[CH3]',
#  '[N-3]',
#  '[Hf+2]',
#  '[Th]',
#  '[Sb+3]',
#  '%14',
#  '[Cr+2]',
#  '[Ru+2]',
#  '[Hf+4]',
#  '[14C]',
#  '[Ta]',
#  '[Tl+]',
#  '[B+]',
#  '[Os+4]',
#  '[PdH2]',
#  '[Pd-]',
#  '[Cd+2]',
#  '[Co+3]',
#  '[S+4]',
#  '[Nb+5]',
#  '[123I]',
#  '[c+]',
#  '[Rb+]',
#  '[V+2]',
#  '[CH3+]',
#  '[Ag+2]',
#  '[cH+]',
#  '[Mn+3]',
#  '[Se-]',
#  '[As-]',
#  '[Eu+3]',
#  '[SH2]',
#  '[Sm+3]',
#  '[IH+]',
#  '%15',
#  '[OH3+]',
#  '[PH3]',
#  '[IH2+]',
#  '[SH2+]',
#  '[Ir+3]',
#  '[AlH3]',
#  '[Sc]',
#  '[Yb]',
#  '[15NH2]',
#  '[Lu]',
#  '[sH+]',
#  '[Gd]',
#  '[18F-]',
#  '[SH3+]',
#  '[SnH4]',
#  '[TeH]',
#  '[Si@@H]',
#  '[Ga+3]',
#  '[CaH2]',
#  '[Tl]',
#  '[Ta+5]',
#  '[GeH]',
#  '[Br+]',
#  '[Sr]',
#  '[Tl+3]',
#  '[Sm+2]',
#  '[PH5]',
#  '%16',
#  '[N@@+]',
#  '[Au+3]',
#  '[C-4]',
#  '[Nd]',
#  '[Ti+]',
#  '[IH]',
#  '[N@+]',
#  '[125I]',
#  '[Eu]',
#  '[Sn+3]',
#  '[Nb]',
#  '[Er+3]',
#  '[123I-]',
#  '[14c]',
#  '%17',
#  '[SnH2]',
#  '[YH]',
#  '[Sb+5]',
#  '[Pr+3]',
#  '[Ir+]',
#  '[N+3]',
#  '[AlH2]',
#  '[19F]',
#  '%18',
#  '[Tb]',
#  '[14CH]',
#  '[Mo+4]',
#  '[Si+]',
#  '[BH]',
#  '[Be]',
#  '[Rb]',
#  '[pH]',
#  '%19',
#  '%20',
#  '[Xe]',
#  '[Ir-]',
#  '[Be+2]',
#  '[C+4]',
#  '[RuH2]',
#  '[15NH]',
#  '[U+2]',
#  '[Au-]',
#  '%21',
#  '%22',
#  '[Au+]',
#  '[15n]',
#  '[Al+2]',
#  '[Tb+3]',
#  '[15N]',
#  '[V+3]',
#  '[W+6]',
#  '[14CH3]',
#  '[Cr+4]',
#  '[ClH+]',
#  'b',
#  '[Ti+6]',
#  '[Nd+]',
#  '[Zr+]',
#  '[PH2+]',
#  '[Fm]',
#  '[N@H+]',
#  '[RuH]',
#  '[Dy+3]',
#  '%23',
#  '[Hf+3]',
#  '[W+4]',
#  '[11C]',
#  '[13CH]',
#  '[Er]',
#  '[124I]',
#  '[LaH]',
#  '[F]',
#  '[siH]',
#  '[Ga+]',
#  '[Cm]',
#  '[GeH3]',
#  '[IH-]',
#  '[U+6]',
#  '[SeH+]',
#  '[32P]',
#  '[SeH-]',
#  '[Pt-]',
#  '[Ir+2]',
#  '[se+]',
#  '[U]',
#  '[F+]',
#  '[BH2]',
#  '[As+]',
#  '[Cf]',
#  '[ClH2+]',
#  '[Ni+]',
#  '[TeH3]',
#  '[SbH2]',
#  '[Ag+3]',
#  '%24',
#  '[18O]',
#  '[PH4]',
#  '[Os+2]',
#  '[Na-]',
#  '[Sb+2]',
#  '[V+4]',
#  '[Ho+3]',
#  '[68Ga]',
#  '[PH-]',
#  '[Bi+2]',
#  '[Ce+2]',
#  '[Pd+3]',
#  '[99Tc]',
#  '[13C@@H]',
#  '[Fe+6]',
#  '[c]',
#  '[GeH2]',
#  '[10B]',
#  '[Cu+3]',
#  '[Mo+2]',
#  '[Cr+]',
#  '[Pd+4]',
#  '[Dy]',
#  '[AsH]',
#  '[Ba+]',
#  '[SeH2]',
#  '[In+]',
#  '[TeH2]',
#  '[BrH+]',
#  '[14cH]',
#  '[W+]',
#  '[13C@H]',
#  '[AsH2]',
#  '[In+2]',
#  '[N+2]',
#  '[N@@H+]',
#  '[SbH]',
#  '[60Co]',
#  '[AsH4+]',
#  '[AsH3]',
#  '[18OH]',
#  '[Ru-2]',
#  '[Na-2]',
#  '[CuH2]',
#  '[31P]',
#  '[Ti+5]',
#  '[35S]',
#  '[P@@H]',
#  '[ArH]',
#  '[Co+]',
#  '[Zr-2]',
#  '[BH2-]',
#  '[131I]',
#  '[SH5]',
#  '[VH]',
#  '[B+2]',
#  '[Yb+2]',
#  '[14C@H]',
#  '[211At]',
#  '[NH3+2]',
#  '[IrH]',
#  '[IrH2]',
#  '[Rh-]',
#  '[Cr-]',
#  '[Sb+]',
#  '[Ni+3]',
#  '[TaH3]',
#  '[Tl+2]',
#  '[64Cu]',
#  '[Tc]',
#  '[Cd+]',
#  '[1H]',
#  '[15nH]',
#  '[AlH2+]',
#  '[FH+2]',
#  '[BiH3]',
#  '[Ru-]',
#  '[Mo+6]',
#  '[AsH+]',
#  '[BaH2]',
#  '[BaH]',
#  '[Fe+4]',
#  '[229Th]',
#  '[Th+4]',
#  '[As+3]',
#  '[NH+3]',
#  '[P@H]',
#  '[Li-]',
#  '[7NaH]',
#  '[Bi+]',
#  '[PtH+2]',
#  '[p-]',
#  '[Re+5]',
#  '[NiH]',
#  '[Ni-]',
#  '[Xe+]',
#  '[Ca+]',
#  '[11c]',
#  '[Rh+4]',
#  '[AcH]',
#  '[HeH]',
#  '[Sc+2]',
#  '[Mn+]',
#  '[UH]',
#  '[14CH2]',
#  '[SiH4+]',
#  '[18OH2]',
#  '[Ac-]',
#  '[Re+4]',
#  '[118Sn]',
#  '[153Sm]',
#  '[P+2]',
#  '[9CH]',
#  '[9CH3]',
#  '[Y-]',
#  '[NiH2]',
#  '[Si+2]',
#  '[Mn+6]',
#  '[ZrH2]',
#  '[C-2]',
#  '[Bi+5]',
#  '[24NaH]',
#  '[Fr]',
#  '[15CH]',
#  '[Se+]',
#  '[At]',
#  '[P-3]',
#  '[124I-]',
#  '[CuH2-]',
#  '[Nb+4]',
#  '[Nb+3]',
#  '[MgH]',
#  '[Ir+4]',
#  '[67Ga+3]',
#  '[67Ga]',
#  '[13N]',
#  '[15OH2]',
#  '[2NH]',
#  '[Ho]',
#  '[Cn]']

# %%
useful_vocab = sm_old_vocab[17:]

# %%
useful_vocab
# Out:
# ['c',
#  'C',
#  '(',
#  ')',
#  'O',
#  '1',
#  '2',
#  '=',
#  'N',
#  '.',
#  'n',
#  '3',
#  'F',
#  'Cl',
#  '>>',
#  '~',
#  '-',
#  '4',
#  '[C@H]',
#  'S',
#  '[C@@H]',
#  '[O-]',
#  'Br',
#  '#',
#  '/',
#  '[nH]',
#  '[N+]',
#  's',
#  '5',
#  'o',
#  'P',
#  '[Na+]',
#  '[Si]',
#  'I',
#  '[Na]',
#  '[Pd]',
#  '[K+]',
#  '[K]',
#  '[P]',
#  'B',
#  '[C@]',
#  '[C@@]',
#  '[Cl-]',
#  '6',
#  '[OH-]',
#  '\\',
#  '[N-]',
#  '[Li]',
#  '[H]',
#  '[2H]',
#  '[NH4+]',
#  '[c-]',
#  '[P-]',
#  '[Cs+]',
#  '[Li+]',
#  '[Cs]',
#  '[NaH]',
#  '[H-]',
#  '[O+]',
#  '[BH4-]',
#  '[Cu]',
#  '7',
#  '[Mg]',
#  '[Fe+2]',
#  '[n+]',
#  '[Sn]',
#  '[BH-]',
#  '[Pd+2]',
#  '[CH]',
#  '[I-]',
#  '[Br-]',
#  '[C-]',
#  '[Zn]',
#  '[B-]',
#  '[F-]',
#  '[Al]',
#  '[P+]',
#  '[BH3-]',
#  '[Fe]',
#  '[C]',
#  '[AlH4]',
#  '[Ni]',
#  '[SiH]',
#  '8',
#  '[Cu+2]',
#  '[Mn]',
#  '[AlH]',
#  '[nH+]',
#  '[AlH4-]',
#  '[O-2]',
#  '[Cr]',
#  '[Mg+2]',
#  '[NH3+]',
#  '[S@]',
#  '[Pt]',
#  '[Al+3]',
#  '[S@@]',
#  '[S-]',
#  '[Ti]',
#  '[Zn+2]',
#  '[PH]',
#  '[NH2+]',
#  '[Ru]',
#  '[Ag+]',
#  '[S+]',
#  '[I+3]',
#  '[NH+]',
#  '[Ca+2]',
#  '[Ag]',
#  '9',
#  '[Os]',
#  '[Se]',
#  '[SiH2]',
#  '[Ca]',
#  '[Ti+4]',
#  '[Ac]',
#  '[Cu+]',
#  '[S]',
#  '[Rh]',
#  '[Cl+3]',
#  '[cH-]',
#  '[Zn+]',
#  '[O]',
#  '[Cl+]',
#  '[SH]',
#  '[H+]',
#  '[Pd+]',
#  '[se]',
#  '[PH+]',
#  '[I]',
#  '[Pt+2]',
#  '[C+]',
#  '[Mg+]',
#  '[Hg]',
#  '[W]',
#  '[SnH]',
#  '[SiH3]',
#  '[Fe+3]',
#  '[NH]',
#  '[Mo]',
#  '[CH2+]',
#  '%10',
#  '[CH2-]',
#  '[CH2]',
#  '[n-]',
#  '[Ce+4]',
#  '[NH-]',
#  '[Co]',
#  '[I+]',
#  '[PH2]',
#  '[Pt+4]',
#  '[Ce]',
#  '[B]',
#  '[Sn+2]',
#  '[Ba+2]',
#  '%11',
#  '[Fe-3]',
#  '[18F]',
#  '[SH-]',
#  '[Pb+2]',
#  '[Os-2]',
#  '[Zr+4]',
#  '[N]',
#  '[Ir]',
#  '[Bi]',
#  '[Ni+2]',
#  '[P@]',
#  '[Co+2]',
#  '[s+]',
#  '[As]',
#  '[P+3]',
#  '[Hg+2]',
#  '[Yb+3]',
#  '[CH-]',
#  '[Zr+2]',
#  '[Mn+2]',
#  '[CH+]',
#  '[In]',
#  '[KH]',
#  '[Ce+3]',
#  '[Zr]',
#  '[AlH2-]',
#  '[OH2+]',
#  '[Ti+3]',
#  '[Rh+2]',
#  '[Sb]',
#  '[S-2]',
#  '%12',
#  '[P@@]',
#  '[Si@H]',
#  '[Mn+4]',
#  'p',
#  '[Ba]',
#  '[NH2-]',
#  '[Ge]',
#  '[Pb+4]',
#  '[Cr+3]',
#  '[Au]',
#  '[LiH]',
#  '[Sc+3]',
#  '[o+]',
#  '[Rh-3]',
#  '%13',
#  '[Br]',
#  '[Sb-]',
#  '[S@+]',
#  '[I+2]',
#  '[Ar]',
#  '[V]',
#  '[Cu-]',
#  '[Al-]',
#  '[Te]',
#  '[13c]',
#  '[13C]',
#  '[Cl]',
#  '[PH4+]',
#  '[SiH4]',
#  '[te]',
#  '[CH3-]',
#  '[S@@+]',
#  '[Rh+3]',
#  '[SH+]',
#  '[Bi+3]',
#  '[Br+2]',
#  '[La]',
#  '[La+3]',
#  '[Pt-2]',
#  '[N@@]',
#  '[PH3+]',
#  '[N@]',
#  '[Si+4]',
#  '[Sr+2]',
#  '[Al+]',
#  '[Pb]',
#  '[SeH]',
#  '[Si-]',
#  '[V+5]',
#  '[Y+3]',
#  '[Re]',
#  '[Ru+]',
#  '[Sm]',
#  '*',
#  '[3H]',
#  '[NH2]',
#  '[Ag-]',
#  '[13CH3]',
#  '[OH+]',
#  '[Ru+3]',
#  '[OH]',
#  '[Gd+3]',
#  '[13CH2]',
#  '[In+3]',
#  '[Si@@]',
#  '[Si@]',
#  '[Ti+2]',
#  '[Sn+]',
#  '[Cl+2]',
#  '[AlH-]',
#  '[Pd-2]',
#  '[SnH3]',
#  '[B+3]',
#  '[Cu-2]',
#  '[Nd+3]',
#  '[Pb+3]',
#  '[13cH]',
#  '[Fe-4]',
#  '[Ga]',
#  '[Sn+4]',
#  '[Hg+]',
#  '[11CH3]',
#  '[Hf]',
#  '[Pr]',
#  '[Y]',
#  '[S+2]',
#  '[Cd]',
#  '[Cr+6]',
#  '[Zr+3]',
#  '[Rh+]',
#  '[CH3]',
#  '[N-3]',
#  '[Hf+2]',
#  '[Th]',
#  '[Sb+3]',
#  '%14',
#  '[Cr+2]',
#  '[Ru+2]',
#  '[Hf+4]',
#  '[14C]',
#  '[Ta]',
#  '[Tl+]',
#  '[B+]',
#  '[Os+4]',
#  '[PdH2]',
#  '[Pd-]',
#  '[Cd+2]',
#  '[Co+3]',
#  '[S+4]',
#  '[Nb+5]',
#  '[123I]',
#  '[c+]',
#  '[Rb+]',
#  '[V+2]',
#  '[CH3+]',
#  '[Ag+2]',
#  '[cH+]',
#  '[Mn+3]',
#  '[Se-]',
#  '[As-]',
#  '[Eu+3]',
#  '[SH2]',
#  '[Sm+3]',
#  '[IH+]',
#  '%15',
#  '[OH3+]',
#  '[PH3]',
#  '[IH2+]',
#  '[SH2+]',
#  '[Ir+3]',
#  '[AlH3]',
#  '[Sc]',
#  '[Yb]',
#  '[15NH2]',
#  '[Lu]',
#  '[sH+]',
#  '[Gd]',
#  '[18F-]',
#  '[SH3+]',
#  '[SnH4]',
#  '[TeH]',
#  '[Si@@H]',
#  '[Ga+3]',
#  '[CaH2]',
#  '[Tl]',
#  '[Ta+5]',
#  '[GeH]',
#  '[Br+]',
#  '[Sr]',
#  '[Tl+3]',
#  '[Sm+2]',
#  '[PH5]',
#  '%16',
#  '[N@@+]',
#  '[Au+3]',
#  '[C-4]',
#  '[Nd]',
#  '[Ti+]',
#  '[IH]',
#  '[N@+]',
#  '[125I]',
#  '[Eu]',
#  '[Sn+3]',
#  '[Nb]',
#  '[Er+3]',
#  '[123I-]',
#  '[14c]',
#  '%17',
#  '[SnH2]',
#  '[YH]',
#  '[Sb+5]',
#  '[Pr+3]',
#  '[Ir+]',
#  '[N+3]',
#  '[AlH2]',
#  '[19F]',
#  '%18',
#  '[Tb]',
#  '[14CH]',
#  '[Mo+4]',
#  '[Si+]',
#  '[BH]',
#  '[Be]',
#  '[Rb]',
#  '[pH]',
#  '%19',
#  '%20',
#  '[Xe]',
#  '[Ir-]',
#  '[Be+2]',
#  '[C+4]',
#  '[RuH2]',
#  '[15NH]',
#  '[U+2]',
#  '[Au-]',
#  '%21',
#  '%22',
#  '[Au+]',
#  '[15n]',
#  '[Al+2]',
#  '[Tb+3]',
#  '[15N]',
#  '[V+3]',
#  '[W+6]',
#  '[14CH3]',
#  '[Cr+4]',
#  '[ClH+]',
#  'b',
#  '[Ti+6]',
#  '[Nd+]',
#  '[Zr+]',
#  '[PH2+]',
#  '[Fm]',
#  '[N@H+]',
#  '[RuH]',
#  '[Dy+3]',
#  '%23',
#  '[Hf+3]',
#  '[W+4]',
#  '[11C]',
#  '[13CH]',
#  '[Er]',
#  '[124I]',
#  '[LaH]',
#  '[F]',
#  '[siH]',
#  '[Ga+]',
#  '[Cm]',
#  '[GeH3]',
#  '[IH-]',
#  '[U+6]',
#  '[SeH+]',
#  '[32P]',
#  '[SeH-]',
#  '[Pt-]',
#  '[Ir+2]',
#  '[se+]',
#  '[U]',
#  '[F+]',
#  '[BH2]',
#  '[As+]',
#  '[Cf]',
#  '[ClH2+]',
#  '[Ni+]',
#  '[TeH3]',
#  '[SbH2]',
#  '[Ag+3]',
#  '%24',
#  '[18O]',
#  '[PH4]',
#  '[Os+2]',
#  '[Na-]',
#  '[Sb+2]',
#  '[V+4]',
#  '[Ho+3]',
#  '[68Ga]',
#  '[PH-]',
#  '[Bi+2]',
#  '[Ce+2]',
#  '[Pd+3]',
#  '[99Tc]',
#  '[13C@@H]',
#  '[Fe+6]',
#  '[c]',
#  '[GeH2]',
#  '[10B]',
#  '[Cu+3]',
#  '[Mo+2]',
#  '[Cr+]',
#  '[Pd+4]',
#  '[Dy]',
#  '[AsH]',
#  '[Ba+]',
#  '[SeH2]',
#  '[In+]',
#  '[TeH2]',
#  '[BrH+]',
#  '[14cH]',
#  '[W+]',
#  '[13C@H]',
#  '[AsH2]',
#  '[In+2]',
#  '[N+2]',
#  '[N@@H+]',
#  '[SbH]',
#  '[60Co]',
#  '[AsH4+]',
#  '[AsH3]',
#  '[18OH]',
#  '[Ru-2]',
#  '[Na-2]',
#  '[CuH2]',
#  '[31P]',
#  '[Ti+5]',
#  '[35S]',
#  '[P@@H]',
#  '[ArH]',
#  '[Co+]',
#  '[Zr-2]',
#  '[BH2-]',
#  '[131I]',
#  '[SH5]',
#  '[VH]',
#  '[B+2]',
#  '[Yb+2]',
#  '[14C@H]',
#  '[211At]',
#  '[NH3+2]',
#  '[IrH]',
#  '[IrH2]',
#  '[Rh-]',
#  '[Cr-]',
#  '[Sb+]',
#  '[Ni+3]',
#  '[TaH3]',
#  '[Tl+2]',
#  '[64Cu]',
#  '[Tc]',
#  '[Cd+]',
#  '[1H]',
#  '[15nH]',
#  '[AlH2+]',
#  '[FH+2]',
#  '[BiH3]',
#  '[Ru-]',
#  '[Mo+6]',
#  '[AsH+]',
#  '[BaH2]',
#  '[BaH]',
#  '[Fe+4]',
#  '[229Th]',
#  '[Th+4]',
#  '[As+3]',
#  '[NH+3]',
#  '[P@H]',
#  '[Li-]',
#  '[7NaH]',
#  '[Bi+]',
#  '[PtH+2]',
#  '[p-]',
#  '[Re+5]',
#  '[NiH]',
#  '[Ni-]',
#  '[Xe+]',
#  '[Ca+]',
#  '[11c]',
#  '[Rh+4]',
#  '[AcH]',
#  '[HeH]',
#  '[Sc+2]',
#  '[Mn+]',
#  '[UH]',
#  '[14CH2]',
#  '[SiH4+]',
#  '[18OH2]',
#  '[Ac-]',
#  '[Re+4]',
#  '[118Sn]',
#  '[153Sm]',
#  '[P+2]',
#  '[9CH]',
#  '[9CH3]',
#  '[Y-]',
#  '[NiH2]',
#  '[Si+2]',
#  '[Mn+6]',
#  '[ZrH2]',
#  '[C-2]',
#  '[Bi+5]',
#  '[24NaH]',
#  '[Fr]',
#  '[15CH]',
#  '[Se+]',
#  '[At]',
#  '[P-3]',
#  '[124I-]',
#  '[CuH2-]',
#  '[Nb+4]',
#  '[Nb+3]',
#  '[MgH]',
#  '[Ir+4]',
#  '[67Ga+3]',
#  '[67Ga]',
#  '[13N]',
#  '[15OH2]',
#  '[2NH]',
#  '[Ho]',
#  '[Cn]']

# %%
len(useful_vocab)
# Out:
# 576

# %%
with open(sf_like_tokenizer_path, "r") as f:
    vocab = json.load(f)

# %%
vocab
# Out:
# {'version': '1.0',
#  'truncation': None,
#  'padding': None,
#  'added_tokens': [{'id': 0,
#    'content': '<s>',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': True},
#   {'id': 1,
#    'content': '<pad>',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': True},
#   {'id': 2,
#    'content': '</s>',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': True},
#   {'id': 3,
#    'content': '<unk>',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': True},
#   {'id': 5,
#    'content': '<mask>',
#    'single_word': False,
#    'lstrip': True,
#    'rstrip': False,
#    'normalized': True,
#    'special': True},
#   {'id': 6,
#    'content': '[Canon]',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 7,
#    'content': '[Rand]',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False}],
#  'normalizer': None,
#  'pre_tokenizer': {'type': 'ByteLevel',
#   'add_prefix_space': False,
#   'trim_offsets': True,
#   'use_regex': True},
#  'post_processor': {'type': 'RobertaProcessing',
#   'sep': ['</s>', 2],
#   'cls': ['<s>', 0],
#   'trim_offsets': True,
#   'add_prefix_space': False},
#  'decoder': {'type': 'ByteLevel',
#   'add_prefix_space': True,
#   'trim_offsets': True,
#   'use_regex': True},
#  'model': {'type': 'BPE',
#   'dropout': None,
#   'unk_token': None,
#   'continuing_subword_prefix': '',
#   'end_of_word_suffix': '',
#   'fuse_unk': False,
#   'vocab': {'<s>': 0, '<pad>': 1, '</s>': 2, '<unk>': 3},
#   'merges': []}}

# %%
for i in range(8, 8+576):
    template = {'id': i,
       'content': useful_vocab[i-8],
       'single_word': False,
       'lstrip': True,
       'rstrip': False,
       'normalized': True,
       'special': True}

    vocab["added_tokens"].append(template)

# %%
vocab
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 vocab
#
# NameError: name 'vocab' is not defined

# %%
len(vocab["added_tokens"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 len(vocab["added_tokens"])
#
# NameError: name 'vocab' is not defined
